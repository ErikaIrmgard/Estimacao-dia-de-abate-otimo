# %%
# ============================================
# Modelo Sigmoide (com escolha automática de modelo)
# Notebook "rodável" (sem argparse / sem terminal)
# Atualizado: PATCH para A em Logístico quando vier NaN/ausente
# ============================================

import numpy as np
import pandas as pd
from pathlib import Path
from scipy.optimize import curve_fit, brentq
from pandas.api.types import is_numeric_dtype

# ============================== CONFIG =================================
ARQUIVO_ENTRADA = Path(r"C:\Users\erika\OneDrive\Área de Trabalho\AVICOLA\LOTES.xlsx")
ARQUIVO_SAIDA   = Path(r"C:\Users\erika\OneDrive\Área de Trabalho\AVICOLA\resultado_modelagem_Sigmoide.csv")

ALVO_PESO  = 2800.0     # alvo para idade ótima
DIA_PREVER = 42         # dia para prever o peso

# limites biológicos
IDADE_MIN_BIO = 28.0
IDADE_MAX_BIO = 65.0
ASSINT_MIN = 2000.0
ASSINT_MAX = 6000.0

print("Entrada:", ARQUIVO_ENTRADA)
print("Saída  :", ARQUIVO_SAIDA)

# ========================= FUNÇÕES AUXILIARES ==========================
def ensure_numeric_pt(series):
    """Converte série para numérica, aceitando strings com vírgula decimal."""
    if is_numeric_dtype(series):
        return pd.to_numeric(series, errors="coerce")
    s = series.astype(str).str.strip()
    s = s.replace({"": np.nan, "nan": np.nan, "None": np.nan})
    s = s.str.replace(".", "", regex=False).str.replace(",", ".", regex=False)
    return pd.to_numeric(s, errors="coerce")

def f_richards(t, A, K, B, M, v):
    t = np.asarray(t, dtype=float)
    return A + (K - A) / (1.0 + np.exp(-B * (t - M))) ** (1.0 / v)

def f_gompertz(t, A, B, M):
    t = np.asarray(t, dtype=float)
    return A * np.exp(-np.exp(-B * (t - M)))

def f_logistico(t, K, A, B):
    t = np.asarray(t, dtype=float)
    return K / (1.0 + A * np.exp(-B * t))

def f_vonb(t, K, A, B):
    t = np.asarray(t, dtype=float)
    return K * np.power((1.0 - A * np.exp(-B * t)), 3)

def safe_curve_fit(func, x, y, p0, bounds=None, maxfev=15000):
    try:
        if bounds is None:
            popt, _ = curve_fit(func, x, y, p0=p0, maxfev=maxfev)
        else:
            popt, _ = curve_fit(func, x, y, p0=p0, bounds=bounds, maxfev=maxfev)
        yhat = func(x, *popt)
        resid = y - yhat
        return popt, resid
    except Exception:
        return None, None

def aic_from_residuals(residuals, k):
    if residuals is None:
        return np.inf
    n = residuals.size
    if n == 0:
        return np.inf
    rss = float(np.sum(residuals ** 2))
    if rss <= 0:
        return np.inf
    return n * np.log(rss / n) + 2 * k

def r2_from_residuals(y, residuals):
    ss_res = float(np.sum(residuals ** 2))
    ss_tot = float(np.sum((y - np.mean(y)) ** 2))
    return 1 - ss_res / ss_tot if ss_tot > 0 else np.nan

def invert_time_for_weight(func, params, alvo, t_min=0.0, t_max=200.0):
    """Encontra t tal que func(t,*params)=alvo via brentq com expansão de intervalo."""
    def g(t):
        return func(np.array([t]), *params)[0] - alvo
    cap, step = 400.0, 50.0
    while t_max <= cap and np.sign(g(t_min)) == np.sign(g(t_max)):
        t_max += step
    if np.sign(g(t_min)) == np.sign(g(t_max)):
        return np.nan
    try:
        root = brentq(g, t_min, t_max, maxiter=200)
        return float(root) if root >= 0 else np.nan
    except Exception:
        return np.nan

# ============================== DADOS ==================================
df_raw = pd.read_excel(ARQUIVO_ENTRADA)

rename_map = {
    "CODIGO_DO_PRODUTOR": "produtor",
    "SEXO_DO_LOTE": "sexo",
    "LINHAGEM": "raca",
    "TIPO_AVIARIO": "tipo_aviario",
    "IDADE": "idade_dias",
    "PESO": "peso",
}
df = df_raw.rename(columns=rename_map)

df["idade_dias"] = ensure_numeric_pt(df["idade_dias"])
df["peso"]       = ensure_numeric_pt(df["peso"])
df = df.dropna(subset=["idade_dias", "peso"]).copy()

# strings limpas nas chaves
for c in ["produtor", "sexo", "raca", "tipo_aviario"]:
    df[c] = df[c].astype(str).str.strip()

# ===== núm. de lotes por (produtor, sexo, raca, tipo_aviario)
col_lote = "NOME_DO_LOTE"
if col_lote not in df.columns:
    raise ValueError("Coluna de identificação do lote não encontrada (esperado 'NOME_DO_LOTE').")

lotes_por_grp = (
    df
    .groupby(["produtor", "sexo", "raca", "tipo_aviario"], dropna=False)[col_lote]
    .nunique()
    .reset_index()
    .rename(columns={col_lote: "num_lotes"})
)

# ===== média por idade (curva do produtor)
df_grp = (
    df
    .groupby(["produtor", "sexo", "raca", "tipo_aviario", "idade_dias"], dropna=False, as_index=False)["peso"]
    .mean()
)

df_grp = df_grp.merge(
    lotes_por_grp,
    on=["produtor", "sexo", "raca", "tipo_aviario"],
    how="left"
)

df = df_grp  # base para modelagem por produtor

chaves_grupo = ["produtor", "sexo", "raca", "tipo_aviario"]
chaves_base  = ["produtor", "sexo", "raca", "tipo_aviario"]

# peso REAL observado aos 42 dias (para fallback do Logístico)
peso_real_42_tbl = df[df["idade_dias"] == 42].copy().set_index(chaves_grupo)["peso"]

# ======================= CURVAS BASE (GOMPERTZ) =======================
print("\nAjustando curvas-base (Gompertz)...")
base_models = {}

for chave, gbase in df.groupby(chaves_base, dropna=False):
    gbase = gbase.sort_values("idade_dias")
    x = gbase["idade_dias"].to_numpy(float)
    y = gbase["peso"].to_numpy(float)

    ymin, ymax = float(np.min(y)), float(np.max(y))
    xmin, xmax = float(np.min(x)), float(np.max(x))
    xmed = float(np.median(x))

    A_low  = max(ymax * 0.9, ASSINT_MIN)
    A_high = min(ymax * 3.0, ASSINT_MAX)

    p0 = [min(max(ymax * 1.10, A_low), A_high), 0.03, xmed]
    bounds = ([A_low, 1e-6, xmin - 20.0],
              [A_high, 1.0, xmax + 20.0])

    pg, rg = safe_curve_fit(f_gompertz, x, y, p0=p0, bounds=bounds)
    if pg is None:
        print("Falha curva-base para chave:", chave)
        continue

    A_base, B_base, M_base = pg
    base_models[chave] = (A_base, B_base, M_base)

    print(f"Base {chave} -> A={A_base:.1f} B={B_base:.4f} M={M_base:.1f}")

def chave_base_from_row(row):
    return (row["produtor"], row["sexo"], row["raca"], row["tipo_aviario"])

# ================= AJUSTE POR PRODUTOR + ESCOLHA DE MODELO ===============
linhas = []

for chave_grp, g in df.groupby(chaves_grupo, dropna=False):

    g = g.sort_values("idade_dias")
    x_all = g["idade_dias"].to_numpy(float)
    y_all = g["peso"].to_numpy(float)
    n = len(x_all)

    ymin, ymax = float(np.min(y_all)), float(np.max(y_all))
    xmin, xmax = float(np.min(x_all)), float(np.max(x_all))
    xmed = float(np.median(x_all))

    uma_linha = g.iloc[0]
    chave_b = chave_base_from_row(uma_linha)
    if chave_b not in base_models:
        chave_b = next(iter(base_models.keys()))
    A_base, B_base_base, M_base_base = base_models[chave_b]

    num_lotes = uma_linha.get("num_lotes", np.nan)

    tipo_ajuste = None
    modelo_escolhido = None
    params_escolhidos = (np.nan,) * 5
    R2 = np.nan
    idade_2800 = np.nan
    idade_2800_ajust = np.nan
    flag_idade_2800 = "sem_solucao"
    peso_42 = np.nan
    f_model = None

    # ========= CASO ESPECIAL: produtor com 1 ou 2 lotes -> usa outros produtores (Gompertz)
    if not pd.isna(num_lotes) and int(num_lotes) <= 2:
        prod0, sexo0, raca0, avi0 = uma_linha["produtor"], uma_linha["sexo"], uma_linha["raca"], uma_linha["tipo_aviario"]

        g_pool = df[
            (df["sexo"] == sexo0) &
            (df["raca"] == raca0) &
            (df["tipo_aviario"] == avi0) &
            (df["produtor"] != prod0)
        ].sort_values("idade_dias")

        if len(g_pool) >= 3:
            tipo_ajuste = "gompertz_outros_produtores"
            modelo_escolhido = "Gompertz_outros"

            x_fit = g_pool["idade_dias"].to_numpy(float)
            y_fit = g_pool["peso"].to_numpy(float)

            ymin_f, ymax_f = float(np.min(y_fit)), float(np.max(y_fit))
            xmin_f, xmax_f = float(np.min(x_fit)), float(np.max(x_fit))
            xmed_f = float(np.median(x_fit))

            A_low  = max(ymax_f * 0.9, ASSINT_MIN)
            A_high = min(ymax_f * 3.0, ASSINT_MAX)

            p0_g = [min(max(ymax_f * 1.05, A_low), A_high), 0.03, xmed_f]
            bounds_g = ([A_low, 1e-6, xmin_f - 20.0],
                        [A_high, 1.0, xmax_f + 20.0])

            pg, rg = safe_curve_fit(f_gompertz, x_fit, y_fit, p0=p0_g, bounds=bounds_g)
            if pg is not None:
                A_g, B_g, M_g = pg
                params_escolhidos = (float(A_g), np.nan, float(B_g), float(M_g), np.nan)
                f_model = f_gompertz
                yhat_fit = f_model(x_fit, *pg)
                R2 = r2_from_residuals(y_fit, y_fit - yhat_fit)
                idade_2800 = invert_time_for_weight(f_model, pg, ALVO_PESO, t_min=0.0, t_max=max(200.0, xmax_f + 30.0))
                peso_42 = float(f_model(np.array([DIA_PREVER]), *pg)[0])

    # --------- CASO 1: >= 5 pontos -> ajuste completo -----------
    if modelo_escolhido is None and n >= 5:
        tipo_ajuste = "completo"
        candidatos = []

        A_low  = max(ymax * 0.9, ASSINT_MIN)
        A_high = min(ymax * 3.0, ASSINT_MAX)
        K_low, K_high = A_low, A_high

        # Gompertz
        p0_g = [min(max(ymax * 1.05, A_low), A_high), 0.03, xmed]
        bounds_g = ([A_low, 1e-6, xmin - 20.0], [A_high, 1.0, xmax + 20.0])
        pg, rg = safe_curve_fit(f_gompertz, x_all, y_all, p0=p0_g, bounds=bounds_g)
        if pg is not None:
            candidatos.append(("Gompertz", f_gompertz, pg, aic_from_residuals(rg, 3)))

        # Logístico
        p0_l = [min(max(ymax * 1.05, K_low), K_high), 1.0, 0.03]
        bounds_l = ([K_low, 1e-6, 1e-6], [K_high, 50.0, 1.0])
        pl, rl = safe_curve_fit(f_logistico, x_all, y_all, p0=p0_l, bounds=bounds_l)
        if pl is not None:
            candidatos.append(("Logistico", f_logistico, pl, aic_from_residuals(rl, 3)))

        # Von Bertalanffy
        p0_v = [min(max(ymax * 1.05, K_low), K_high), 0.9, 0.02]
        bounds_v = ([K_low, 0.01, 1e-6], [K_high, 2.0, 1.0])
        pv, rv = safe_curve_fit(f_vonb, x_all, y_all, p0=p0_v, bounds=bounds_v)
        if pv is not None:
            candidatos.append(("VonBertalanffy", f_vonb, pv, aic_from_residuals(rv, 3)))

        # Richards
        p0_r = [ymin, min(max(ymax * 1.05, K_low), K_high), 0.03, xmed, 1.2]
        bounds_r = ([0.0, K_low, 1e-6, xmin - 20.0, 0.2], [ymax * 1.2, K_high, 1.0, xmax + 20.0, 5.0])
        pr, rr = safe_curve_fit(f_richards, x_all, y_all, p0=p0_r, bounds=bounds_r)
        if pr is not None:
            candidatos.append(("Richards", f_richards, pr, aic_from_residuals(rr, 5)))

        if candidatos:
            modelo_escolhido, f_sel, params, _aic = sorted(candidatos, key=lambda z: z[3])[0]
            yhat_all = f_sel(x_all, *params)
            R2 = r2_from_residuals(y_all, y_all - yhat_all)

            idade_2800 = invert_time_for_weight(f_sel, params, ALVO_PESO, t_min=0.0, t_max=max(200.0, xmax + 30.0))
            peso_42 = float(f_sel(np.array([DIA_PREVER]), *params)[0])

            # gravação dos parâmetros (tipos float)  // PATCH: floats garantidos
            if modelo_escolhido == "Gompertz":
                A, B, M = params
                params_escolhidos = (float(A), np.nan, float(B), float(M), np.nan)

            elif modelo_escolhido in ("Logistico", "VonBertalanffy"):
                K, A2, B = params

                # ===== PATCH: reconstrução de A quando inválido (Logístico) =====
                if modelo_escolhido == "Logistico":
                    A_fix = float(A2) if np.isfinite(A2) and A2 > 0 else np.nan
                    if not np.isfinite(A_fix) or A_fix <= 0:
                        # tenta y(42) do grupo
                        try:
                            y_ref = float(peso_real_42_tbl.loc[chave_grp])
                            t_ref = 42.0
                        except Exception:
                            if len(x_all) > 0:
                                idx = int(np.argmin(np.abs(x_all - 42.0)))
                                y_ref = float(y_all[idx])
                                t_ref = float(x_all[idx])
                            else:
                                y_ref, t_ref = np.nan, np.nan
                        if np.isfinite(y_ref) and y_ref > 0 and np.isfinite(K) and np.isfinite(B):
                            A_fix = (K / y_ref - 1.0) * np.exp(B * t_ref)
                    A2 = A_fix

                # salva nas colunas (A, K, B, M, v)
                params_escolhidos = (float(A2) if np.isfinite(A2) else np.nan,
                                     float(K), float(B), np.nan, np.nan)

            elif modelo_escolhido == "Richards":
                A, K, B, M, v = params
                params_escolhidos = (float(A), float(K), float(B), float(M), float(v))

            f_model = f_sel

    # --------- CASO 2: 2 a 4 pontos -> Gompertz com A_base fixo -----
    if modelo_escolhido is None and 2 <= n <= 4:
        tipo_ajuste = "parcial_gompertz_base"
        def gompertz_parcial(t, B, M): return f_gompertz(t, A_base, B, M)

        p0 = [0.03, xmed]
        bounds = ([1e-6, xmin - 20.0], [1.0,  xmax + 20.0])
        params_parc, r_parc = safe_curve_fit(gompertz_parcial, x_all, y_all, p0=p0, bounds=bounds)
        if params_parc is not None:
            B_parc, M_parc = params_parc
            modelo_escolhido = "Gompertz_baseA"
            yhat_all = gompertz_parcial(x_all, B_parc, M_parc)
            R2 = r2_from_residuals(y_all, y_all - yhat_all)
            idade_2800 = invert_time_for_weight(lambda t, b, m: f_gompertz(t, A_base, b, m),
                                                (B_parc, M_parc), ALVO_PESO,
                                                t_min=0.0, t_max=max(200.0, xmax + 30.0))
            peso_42 = float(f_gompertz(np.array([DIA_PREVER]), A_base, B_parc, M_parc)[0])
            params_escolhidos = (float(A_base), np.nan, float(B_parc), float(M_parc), np.nan)
            f_model = gompertz_parcial

    # --------- CASO 3: 0 ou 1 ponto -> usa apenas a curva-base ----------
    if modelo_escolhido is None and n <= 1:
        tipo_ajuste = "base_global"
        modelo_escolhido = "Gompertz_base"
        A_b, B_b, M_b = A_base, B_base_base, M_base_base
        params_escolhidos = (float(A_b), np.nan, float(B_b), float(M_b), np.nan)
        R2 = np.nan
        idade_2800 = invert_time_for_weight(f_gompertz, (A_b, B_b, M_b), ALVO_PESO, t_min=0.0, t_max=200.0)
        peso_42 = float(f_gompertz(np.array([DIA_PREVER]), A_b, B_b, M_b)[0])
        f_model = f_gompertz

    # ===== critério biológico para idade 2800
    if not np.isnan(idade_2800):
        flag_idade_2800 = "ok"
        idade_2800_ajust = idade_2800
        if idade_2800 < IDADE_MIN_BIO:
            flag_idade_2800 = "muito_baixa"; idade_2800_ajust = np.nan
        elif idade_2800 > IDADE_MAX_BIO:
            flag_idade_2800 = "muito_alta";  idade_2800_ajust = np.nan
    else:
        flag_idade_2800 = "sem_solucao"; idade_2800_ajust = np.nan

    # ===== LOOCV (quando aplicável)
    R2_cv = np.nan
    rmse_cv = np.nan
    if (f_model is not None and modelo_escolhido is not None and n >= 3 and
        tipo_ajuste not in ["base_global", "gompertz_outros_produtores"]):
        preds = []
        ok = True
        for i in range(n):
            mask = np.ones(n, dtype=bool); mask[i] = False
            x_tr, y_tr = x_all[mask], y_all[mask]

            ymin_t, ymax_t = float(np.min(y_tr)), float(np.max(y_tr))
            xmin_t, xmax_t = float(np.min(x_tr)), float(np.max(x_tr))
            xmed_t = float(np.median(x_tr))

            if tipo_ajuste == "completo":
                if modelo_escolhido == "Gompertz":
                    A_low  = max(ymax_t * 0.9, ASSINT_MIN)
                    A_high = min(ymax_t * 3.0, ASSINT_MAX)
                    p0 = [min(max(ymax_t * 1.05, A_low), A_high), 0.03, xmed_t]
                    bounds = ([A_low, 1e-6, xmin_t - 20.0], [A_high, 1.0, xmax_t + 20.0])
                    pfit, _ = safe_curve_fit(f_gompertz, x_tr, y_tr, p0=p0, bounds=bounds)
                    func = f_gompertz
                elif modelo_escolhido == "Logistico":
                    K_low = max(ymax_t * 0.9, ASSINT_MIN); K_high = min(ymax_t * 3.0, ASSINT_MAX)
                    p0 = [min(max(ymax_t * 1.05, K_low), K_high), 1.0, 0.03]
                    bounds = ([K_low, 1e-6, 1e-6], [K_high, 50.0, 1.0])
                    pfit, _ = safe_curve_fit(f_logistico, x_tr, y_tr, p0=p0, bounds=bounds)
                    func = f_logistico
                elif modelo_escolhido == "VonBertalanffy":
                    K_low = max(ymax_t * 0.9, ASSINT_MIN); K_high = min(ymax_t * 3.0, ASSINT_MAX)
                    p0 = [min(max(ymax_t * 1.05, K_low), K_high), 0.9, 0.02]
                    bounds = ([K_low, 0.01, 1e-6], [K_high, 2.0, 1.0])
                    pfit, _ = safe_curve_fit(f_vonb, x_tr, y_tr, p0=p0, bounds=bounds)
                    func = f_vonb
                elif modelo_escolhido == "Richards":
                    K_low = max(ymax_t * 0.9, ASSINT_MIN); K_high = min(ymax_t * 3.0, ASSINT_MAX)
                    p0 = [ymin_t, min(max(ymax_t * 1.05, K_low), K_high), 0.03, xmed_t, 1.2]
                    bounds = ([0.0, K_low, 1e-6, xmin_t - 20.0, 0.2],
                              [ymax_t * 1.2, K_high, 1.0, xmax_t + 20.0, 5.0])
                    pfit, _ = safe_curve_fit(f_richards, x_tr, y_tr, p0=p0, bounds=bounds)
                    func = f_richards
                else:
                    pfit, func = None, None

            elif tipo_ajuste == "parcial_gompertz_base":
                def gompertz_parcial_cv(t, B, M): return f_gompertz(t, A_base, B, M)
                p0 = [0.03, xmed_t]
                bounds = ([1e-6, xmin_t - 20.0], [1.0,  xmax_t + 20.0])
                pfit, _ = safe_curve_fit(gompertz_parcial_cv, x_tr, y_tr, p0=p0, bounds=bounds)
                func = gompertz_parcial_cv
            else:
                pfit, func = None, None

            if pfit is None or func is None:
                ok = False; break

            y_pred_i = func(np.array([x_all[i]]), *pfit)[0]
            preds.append(y_pred_i)

        if ok and len(preds) == n:
            y_pred = np.array(preds, dtype=float)
            resid_cv = y_all - y_pred
            rmse_cv = float(np.sqrt(np.mean(resid_cv ** 2)))
            R2_cv = r2_from_residuals(y_all, resid_cv)

    # ===== assíntota do modelo + flags
    assint = np.nan
    if modelo_escolhido in ["Gompertz", "Gompertz_baseA", "Gompertz_base", "Gompertz_outros"]:
        assint = params_escolhidos[0]  # A
    elif modelo_escolhido in ["Logistico", "VonBertalanffy", "Richards"]:
        assint = params_escolhidos[1]  # K

    flag_assint = "sem_modelo"
    if not np.isnan(assint):
        flag_assint = "ok"
        if assint < ymax * 0.95:
            flag_assint = "menor_que_observado"
        if assint < ASSINT_MIN:
            flag_assint = "muito_baixa"
        elif assint > ASSINT_MAX:
            flag_assint = "muito_alta"

    # ===== peso REAL aos 42 (se houver) para referência
    try:
        peso_real_42 = float(peso_real_42_tbl.loc[chave_grp])
    except Exception:
        peso_real_42 = np.nan

    # ===== monta linha final (tudo como float quando puder)
    A_out, K_out, B_out, M_out, v_out = params_escolhidos
    linha = list(chave_grp) + [
        tipo_ajuste,
        modelo_escolhido,
        float(A_out) if np.isfinite(A_out) else np.nan,
        float(K_out) if np.isfinite(K_out) else np.nan,
        float(B_out) if np.isfinite(B_out) else np.nan,
        float(M_out) if np.isfinite(M_out) else np.nan,
        float(v_out) if np.isfinite(v_out) else np.nan,
        float(assint) if np.isfinite(assint) else np.nan,
        flag_assint,
        float(R2) if np.isfinite(R2) else np.nan,
        float(R2_cv) if np.isfinite(R2_cv) else np.nan,
        float(rmse_cv) if np.isfinite(rmse_cv) else np.nan,
        float(idade_2800) if np.isfinite(idade_2800) else np.nan,
        float(idade_2800_ajust) if np.isfinite(idade_2800_ajust) else np.nan,
        flag_idade_2800,
        float(peso_42) if np.isfinite(peso_42) else np.nan,
        float(peso_real_42) if np.isfinite(peso_real_42) else np.nan,
        int(n)
    ]
    linhas.append(linha)

# ============================= RESULTADO FINAL ==========================
cols_saida = chaves_grupo + [
    "tipo_ajuste",
    "modelo_escolhido",
    "A", "K", "B", "M", "v",
    "ASSINTOTE",
    "FLAG_ASSINTOTE",
    "R2",
    "R2_LOOCV",
    "RMSE_LOOCV",
    "IDADE_PARA_2800G",
    "IDADE_PARA_2800G_AJUST",
    "FLAG_IDADE_2800",
    "peso_previsto_42",
    "peso_real_42",
    "num_pontos"
]

df_saida = pd.DataFrame(linhas, columns=cols_saida).sort_values(
    "IDADE_PARA_2800G_AJUST", ascending=True
)

print("\n=== Saída (primeiras linhas) ===")
display(df_saida.head(20)) if "display" in globals() else print(df_saida.head(20))

df_saida.to_csv(ARQUIVO_SAIDA, index=False, encoding="utf-8-sig")
print("\n✅ Arquivo gerado em:", ARQUIVO_SAIDA)
# Out:
# Entrada: C:\Users\erika\OneDrive\Área de Trabalho\AVICOLA\LOTES.xlsx
# Saída  : C:\Users\erika\OneDrive\Área de Trabalho\AVICOLA\resultado_modelagem_Sigmoide.csv
#
# Ajustando curvas-base (Gompertz)...
# Base ('10028', 'Fêmeas', 'COBB', 'Convencional 3') -> A=4856.0 B=0.0516 M=30.0
# Base ('10028', 'Fêmeas', 'ROSS', 'Convencional 3') -> A=5092.8 B=0.0473 M=33.4
# Base ('10028', 'Machos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0493 M=32.3
# Base ('10028', 'Machos', 'HUBBARD', 'Convencional 3') -> A=5172.9 B=0.0475 M=32.2
# Base ('10028', 'Mistos', 'COBB', 'Convencional 3') -> A=5519.4 B=0.0488 M=32.9
# Base ('10028', 'Mistos', 'ROSS', 'Convencional 3') -> A=5125.6 B=0.0502 M=32.0
# Base ('1020', 'Fêmeas', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0426 M=35.1
# Base ('1020', 'Machos', 'COBB', 'Convencional 1') -> A=4733.3 B=0.0549 M=28.2
# Base ('1020', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0460 M=34.7
# Base ('1020', 'Mistos', 'ROSS', 'Convencional 1') -> A=3942.0 B=0.0614 M=26.2
# Base ('1022', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5366.4 B=0.0476 M=32.4
# Base ('1022', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=4672.0 B=0.0505 M=30.2
# Base ('1022', 'Machos', 'COBB', 'Convencional 2') -> A=5325.1 B=0.0548 M=29.7
# Base ('1022', 'Machos', 'ROSS', 'Convencional 2') -> A=5966.2 B=0.0496 M=32.9
# Base ('1022', 'Mistos', 'COBB', 'Convencional 2') -> A=5501.2 B=0.0496 M=31.1
# Base ('1022', 'Mistos', 'ROSS', 'Convencional 2') -> A=5825.6 B=0.0456 M=34.7
# Base ('1026', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5347.2 B=0.0476 M=32.9
# Base ('1026', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0400 M=37.6
# Base ('1026', 'Mistos', 'COBB', 'Convencional 2') -> A=4689.3 B=0.0554 M=29.5
# Base ('1026', 'Mistos', 'ROSS', 'Convencional 2') -> A=4593.2 B=0.0550 M=29.1
# Base ('1038', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4830.5 B=0.0508 M=30.2
# Base ('1038', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=4915.5 B=0.0497 M=31.0
# Base ('1038', 'Machos', 'COBB', 'Convencional 1') -> A=5740.4 B=0.0476 M=32.5
# Base ('1038', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0427 M=36.8
# Base ('10489', 'Fêmeas', 'COBB', 'Convencional 2 -') -> A=4976.9 B=0.0490 M=31.7
# Base ('10489', 'Fêmeas', 'ROSS', 'Convencional 2 -') -> A=6000.0 B=0.0446 M=36.3
# Base ('10489', 'Machos', 'COBB', 'Convencional 2 -') -> A=4851.3 B=0.0555 M=29.7
# Base ('10489', 'Mistos', 'COBB', 'Convencional 2 -') -> A=6000.0 B=0.0470 M=35.0
# Base ('10489', 'Mistos', 'ROSS', 'Convencional 2 -') -> A=6000.0 B=0.0441 M=36.4
# Base ('1054', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4700.3 B=0.0515 M=30.5
# Base ('1054', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=4561.2 B=0.0495 M=30.8
# Base ('1054', 'Machos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0535 M=31.5
# Base ('1054', 'Machos', 'ROSS', 'Convencional 1') -> A=6000.0 B=0.0445 M=37.3
# Base ('1054', 'Mistos', 'COBB', 'Convencional 1') -> A=5365.7 B=0.0489 M=32.6
# Base ('1058', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4594.4 B=0.0511 M=29.9
# Base ('1077', 'Fêmeas', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0414 M=35.8
# Base ('1077', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=4122.6 B=0.0526 M=28.8
# Base ('1077', 'Machos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0493 M=32.5
# Base ('1077', 'Mistos', 'COBB', 'Convencional 1') -> A=5820.4 B=0.0458 M=34.1
# Base ('1077', 'Mistos', 'ROSS', 'Convencional 1') -> A=6000.0 B=0.0432 M=36.3
# Base ('10785', 'Fêmeas', 'COBB', 'Convencional 3') -> A=5233.1 B=0.0478 M=32.5
# Base ('10785', 'Machos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0532 M=31.9
# Base ('10785', 'Mistos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0475 M=34.4
# Base ('10785', 'Mistos', 'ROSS', 'Convencional 3') -> A=6000.0 B=0.0465 M=35.3
# Base ('1088', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4984.8 B=0.0507 M=30.9
# Base ('1088', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=4730.5 B=0.0522 M=30.2
# Base ('1088', 'Machos', 'COBB', 'Convencional 1') -> A=5175.2 B=0.0563 M=28.6
# Base ('1088', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0474 M=35.1
# Base ('1088', 'Mistos', 'ROSS', 'Convencional 1') -> A=5415.0 B=0.0441 M=37.2
# Base ('10887', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5853.8 B=0.0451 M=34.3
# Base ('10887', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=4426.0 B=0.0528 M=29.8
# Base ('10887', 'Machos', 'COBB', 'Convencional 2') -> A=4680.9 B=0.0567 M=28.4
# Base ('10887', 'Mistos', 'COBB', 'Convencional 2') -> A=5809.3 B=0.0447 M=36.0
# Base ('10887', 'Mistos', 'ROSS', 'Convencional 2') -> A=5815.3 B=0.0464 M=35.1
# Base ('10927', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5788.6 B=0.0457 M=33.4
# Base ('10927', 'Fêmeas', 'COBB', 'Semi-climatizado') -> A=5136.0 B=0.0501 M=30.6
# Base ('10927', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0436 M=35.8
# Base ('10927', 'Fêmeas', 'ROSS', 'Semi-climatizado') -> A=5228.4 B=0.0458 M=33.1
# Base ('10927', 'Machos', 'COBB', 'Convencional 2') -> A=5933.3 B=0.0477 M=33.8
# Base ('10927', 'Machos', 'COBB', 'Semi-climatizado') -> A=6000.0 B=0.0522 M=32.2
# Base ('10927', 'Machos', 'ROSS', 'Convencional 2') -> A=5147.3 B=0.0544 M=29.8
# Base ('10927', 'Machos', 'ROSS', 'Semi-climatizado') -> A=6000.0 B=0.0493 M=32.5
# Base ('10927', 'Mistos', 'COBB', 'Convencional 2') -> A=5700.5 B=0.0456 M=33.8
# Base ('10927', 'Mistos', 'COBB', 'Semi-climatizado') -> A=4311.1 B=0.0583 M=27.9
# Base ('10927', 'Mistos', 'HUBBARD', 'Convencional 2') -> A=5281.3 B=0.0465 M=33.1
# Base ('10927', 'Mistos', 'ROSS', 'Convencional 2') -> A=5156.4 B=0.0505 M=32.1
# Base ('10927', 'Mistos', 'ROSS', 'Semi-climatizado') -> A=5097.3 B=0.0515 M=30.2
# Base ('1107', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5399.6 B=0.0461 M=32.7
# Base ('1107', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=5455.4 B=0.0467 M=32.7
# Base ('1107', 'Machos', 'COBB', 'Convencional 2') -> A=5474.2 B=0.0532 M=30.0
# Base ('1107', 'Mistos', 'COBB', 'Convencional 2') -> A=5466.7 B=0.0505 M=31.2
# Base ('1107', 'Mistos', 'ROSS', 'Convencional 2') -> A=5839.6 B=0.0470 M=33.4
# Base ('1107', 'Sexados', 'COBB', 'Convencional 2') -> A=4791.0 B=0.0530 M=29.3
# Base ('11086', 'Fêmeas', 'COBB', 'Climatizado 2') -> A=3923.2 B=0.0639 M=25.5
# Base ('11086', 'Machos', 'COBB', 'Climatizado 1') -> A=5359.2 B=0.0551 M=29.3
# Base ('11086', 'Machos', 'COBB', 'Climatizado 2') -> A=4562.9 B=0.0634 M=26.1
# Base ('11086', 'Machos', 'ROSS', 'Climatizado 1') -> A=6000.0 B=0.0503 M=32.1
# Base ('11086', 'Machos', 'ROSS', 'Climatizado 2') -> A=4600.2 B=0.0646 M=25.8
# Base ('11086', 'Mistos', 'COBB', 'Climatizado 1') -> A=5712.6 B=0.0468 M=32.7
# Base ('11086', 'Mistos', 'COBB', 'Climatizado 2') -> A=4631.7 B=0.0569 M=28.5
# Base ('1122', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4226.1 B=0.0571 M=27.8
# Base ('1122', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=6000.0 B=0.0404 M=37.2
# Falha curva-base para chave: ('1122', 'Machos', 'ROSS', 'Convencional 1')
# Base ('1122', 'Mistos', 'COBB', 'Convencional 1') -> A=4602.5 B=0.0559 M=29.3
# Base ('1128', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4303.2 B=0.0532 M=28.7
# Base ('1128', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=4843.9 B=0.0461 M=32.2
# Base ('1128', 'Machos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0460 M=34.1
# Base ('1128', 'Mistos', 'COBB', 'Convencional 1') -> A=4365.0 B=0.0561 M=29.8
# Base ('1128', 'Mistos', 'ROSS', 'Convencional 1') -> A=4831.7 B=0.0546 M=29.8
# Base ('1141', 'Fêmeas', 'COBB', 'Convencional 3') -> A=5923.0 B=0.0431 M=35.9
# Base ('1141', 'Fêmeas', 'ROSS', 'Convencional 3') -> A=5354.2 B=0.0460 M=33.8
# Base ('1141', 'Machos', 'COBB', 'Convencional 3') -> A=4934.9 B=0.0546 M=29.2
# Base ('1141', 'Machos', 'ROSS', 'Convencional 3') -> A=6000.0 B=0.0489 M=33.7
# Base ('1141', 'Mistos', 'COBB', 'Convencional 3') -> A=5012.5 B=0.0531 M=29.9
# Base ('1141', 'Mistos', 'ROSS', 'Convencional 3') -> A=4372.2 B=0.0551 M=29.5
# Base ('1150', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5410.1 B=0.0477 M=32.5
# Base ('1150', 'Mistos', 'COBB', 'Convencional 2') -> A=5138.8 B=0.0524 M=30.6
# Base ('1150', 'Mistos', 'ROSS', 'Convencional 2') -> A=5679.0 B=0.0467 M=34.4
# Base ('1152', 'Fêmeas', 'COBB', 'Climatizado 2') -> A=5626.9 B=0.0443 M=34.2
# Base ('1152', 'Fêmeas', 'COBB', 'Convencional 1') -> A=5718.9 B=0.0442 M=34.7
# Base ('1152', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=5107.6 B=0.0482 M=32.0
# Base ('1152', 'Machos', 'COBB', 'Climatizado 2') -> A=6000.0 B=0.0491 M=32.6
# Base ('1152', 'Machos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0485 M=32.9
# Base ('1152', 'Machos', 'ROSS', 'Climatizado 2') -> A=5898.5 B=0.0488 M=32.6
# Base ('1152', 'Mistos', 'COBB', 'Climatizado 2') -> A=6000.0 B=0.0486 M=33.3
# Base ('1152', 'Mistos', 'COBB', 'Convencional 1') -> A=5527.0 B=0.0485 M=32.5
# Base ('1156', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5145.9 B=0.0485 M=31.7
# Base ('1156', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0424 M=36.2
# Falha curva-base para chave: ('1156', 'Machos', 'COBB', 'Convencional 2')
# Base ('1156', 'Mistos', 'COBB', 'Convencional 2') -> A=3593.5 B=0.0675 M=25.0
# Base ('1156', 'Mistos', 'ROSS', 'Convencional 2') -> A=5427.6 B=0.0494 M=32.9
# Base ('1169', 'Fêmeas', 'COBB', 'Convencional 1') -> A=5262.3 B=0.0487 M=31.9
# Base ('1169', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=5260.2 B=0.0473 M=32.8
# Base ('1169', 'Machos', 'COBB', 'Convencional 1') -> A=4918.5 B=0.0609 M=27.7
# Base ('1169', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0455 M=34.5
# Base ('1169', 'Mistos', 'ROSS', 'Convencional 1') -> A=5340.0 B=0.0490 M=32.0
# Base ('1201', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4462.4 B=0.0553 M=28.1
# Base ('1201', 'Fêmeas', 'COBB', 'Semi-climatizado') -> A=4826.6 B=0.0511 M=30.0
# Base ('1201', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=3933.9 B=0.0621 M=25.9
# Base ('1201', 'Machos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0528 M=31.0
# Base ('1201', 'Machos', 'COBB', 'Semi-climatizado') -> A=5553.7 B=0.0523 M=30.5
# Base ('1201', 'Machos', 'ROSS', 'Semi-climatizado') -> A=6000.0 B=0.0499 M=32.6
# Base ('1201', 'Mistos', 'COBB', 'Convencional 1') -> A=4762.2 B=0.0525 M=30.3
# Base ('1201', 'Mistos', 'ROSS', 'Convencional 1') -> A=5284.6 B=0.0509 M=31.2
# Base ('1201', 'Mistos', 'ROSS', 'Semi-climatizado') -> A=4552.0 B=0.0534 M=29.1
# Base ('13045', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5887.7 B=0.0426 M=35.6
# Base ('13045', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=4947.0 B=0.0509 M=31.3
# Base ('13045', 'Machos', 'COBB', 'Convencional 2') -> A=4483.7 B=0.0589 M=26.1
# Base ('13045', 'Machos', 'ROSS', 'Convencional 2') -> A=4945.6 B=0.0543 M=29.9
# Base ('13045', 'Mistos', 'COBB', 'Convencional 2') -> A=4726.2 B=0.0521 M=30.1
# Base ('13045', 'Mistos', 'ROSS', 'Convencional 2') -> A=5789.6 B=0.0455 M=34.8
# Base ('17105', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4683.5 B=0.0520 M=30.3
# Base ('17105', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=4363.9 B=0.0549 M=29.1
# Base ('17105', 'Machos', 'COBB', 'Convencional 1') -> A=5862.1 B=0.0515 M=32.3
# Base ('17105', 'Machos', 'ROSS', 'Convencional 1') -> A=6000.0 B=0.0493 M=33.7
# Base ('17105', 'Mistos', 'COBB', 'Convencional 1') -> A=4530.1 B=0.0546 M=29.9
# Base ('17105', 'Mistos', 'ROSS', 'Convencional 1') -> A=5280.8 B=0.0508 M=32.2
# Base ('17965', 'Fêmeas', 'COBB', 'Climatizado 1') -> A=6000.0 B=0.0434 M=35.3
# Base ('17965', 'Machos', 'COBB', 'Climatizado 1') -> A=4337.9 B=0.0604 M=26.3
# Base ('17965', 'Machos', 'ROSS', 'Climatizado 1') -> A=4468.2 B=0.0589 M=27.5
# Base ('17965', 'Mistos', 'COBB', 'Climatizado 1') -> A=6000.0 B=0.0468 M=33.8
# Base ('17965', 'Mistos', 'ROSS', 'Climatizado 1') -> A=6000.0 B=0.0453 M=34.5
# Base ('18125', 'Fêmeas', 'COBB', 'Convencional 1') -> A=5016.9 B=0.0522 M=29.6
# Base ('18125', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=4279.1 B=0.0547 M=28.7
# Base ('18125', 'Machos', 'COBB', 'Convencional 1') -> A=5271.7 B=0.0540 M=27.8
# Base ('18125', 'Mistos', 'COBB', 'Convencional 1') -> A=4687.6 B=0.0607 M=26.9
# Base ('18125', 'Mistos', 'ROSS', 'Convencional 1') -> A=4906.5 B=0.0569 M=29.5
# Base ('18345', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4055.8 B=0.0562 M=27.6
# Base ('18345', 'Machos', 'ROSS', 'Convencional 1') -> A=6000.0 B=0.0520 M=31.9
# Base ('18345', 'Mistos', 'COBB', 'Convencional 1') -> A=5527.4 B=0.0495 M=32.5
# Base ('18365', 'Fêmeas', 'COBB', 'Climatizado 2') -> A=6000.0 B=0.0480 M=33.7
# Base ('18365', 'Fêmeas', 'COBB', 'Convencional 2') -> A=4945.8 B=0.0530 M=29.8
# Base ('18365', 'Machos', 'COBB', 'Climatizado 2') -> A=6000.0 B=0.0517 M=31.4
# Base ('18365', 'Machos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0502 M=32.5
# Base ('18365', 'Machos', 'ROSS', 'Climatizado 2') -> A=6000.0 B=0.0517 M=32.0
# Base ('18365', 'Machos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0489 M=32.7
# Base ('18365', 'Mistos', 'COBB', 'Climatizado 2') -> A=6000.0 B=0.0508 M=32.3
# Base ('18365', 'Mistos', 'COBB', 'Convencional 2') -> A=5828.9 B=0.0484 M=33.0
# Base ('18365', 'Mistos', 'ROSS', 'Convencional 2') -> A=5745.7 B=0.0491 M=32.5
# Base ('18505', 'Fêmeas', 'COBB', 'Convencional 1 +') -> A=5426.7 B=0.0481 M=32.6
# Base ('18505', 'Fêmeas', 'ROSS', 'Convencional 1 +') -> A=3583.7 B=0.0613 M=26.4
# Base ('18569', 'Fêmeas', 'COBB', 'Climatizado 2') -> A=5372.0 B=0.0461 M=32.9
# Base ('18569', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4968.0 B=0.0477 M=31.6
# Base ('18569', 'Machos', 'COBB', 'Climatizado 2') -> A=5738.6 B=0.0492 M=32.3
# Base ('18569', 'Machos', 'COBB', 'Convencional 1') -> A=4201.5 B=0.0649 M=25.9
# Base ('18569', 'Mistos', 'COBB', 'Climatizado 2') -> A=4795.6 B=0.0514 M=30.0
# Base ('18569', 'Mistos', 'COBB', 'Convencional 1') -> A=3831.7 B=0.0610 M=27.7
# Base ('18569', 'Mistos', 'ROSS', 'Convencional 1') -> A=4299.4 B=0.0530 M=30.2
# Base ('18693', 'Fêmeas', 'COBB', 'Climatizado 1') -> A=6000.0 B=0.0437 M=35.7
# Base ('18693', 'Machos', 'COBB', 'Climatizado 1') -> A=5821.3 B=0.0507 M=31.8
# Base ('18693', 'Machos', 'ROSS', 'Climatizado 1') -> A=6000.0 B=0.0492 M=33.3
# Base ('18693', 'Mistos', 'COBB', 'Climatizado 1') -> A=5553.8 B=0.0472 M=32.4
# Base ('18693', 'Mistos', 'ROSS', 'Climatizado 1') -> A=5418.1 B=0.0468 M=33.0
# Base ('19210', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4805.9 B=0.0488 M=30.8
# Base ('19210', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=5650.0 B=0.0450 M=34.2
# Base ('19210', 'Mistos', 'COBB', 'Convencional 1') -> A=4155.4 B=0.0573 M=27.4
# Base ('19210', 'Mistos', 'ROSS', 'Convencional 1') -> A=5907.4 B=0.0455 M=34.3
# Base ('19211', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4691.3 B=0.0511 M=30.2
# Base ('19211', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=4984.9 B=0.0489 M=31.5
# Base ('19211', 'Mistos', 'COBB', 'Convencional 1') -> A=5018.5 B=0.0520 M=30.8
# Base ('19211', 'Mistos', 'ROSS', 'Convencional 1') -> A=5110.6 B=0.0514 M=31.8
# Base ('19212', 'Fêmeas', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0444 M=34.7
# Base ('19212', 'Mistos', 'COBB', 'Convencional 1') -> A=5080.5 B=0.0542 M=28.7
# Base ('19212', 'Mistos', 'ROSS', 'Convencional 1') -> A=6000.0 B=0.0453 M=34.9
# Base ('19768', 'Fêmeas', 'COBB', 'Convencional 1') -> A=5131.0 B=0.0462 M=32.9
# Base ('19768', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=6000.0 B=0.0399 M=38.3
# Base ('19768', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0423 M=37.2
# Base ('19768', 'Mistos', 'ROSS', 'Convencional 1') -> A=5898.0 B=0.0415 M=37.1
# Base ('20451', 'Fêmeas', 'COBB', 'Convencional 1') -> A=5228.9 B=0.0471 M=32.4
# Base ('20451', 'Machos', 'HUBBARD', 'Convencional 1') -> A=4763.1 B=0.0520 M=29.7
# Base ('20451', 'Mistos', 'COBB', 'Convencional 1') -> A=5867.3 B=0.0485 M=33.5
# Base ('20451', 'Mistos', 'ROSS', 'Convencional 1') -> A=4032.1 B=0.0591 M=27.4
# Base ('20557', 'Fêmeas', 'COBB', 'Convencional 3') -> A=4974.7 B=0.0497 M=30.4
# Base ('20557', 'Machos', 'COBB', 'Convencional 3') -> A=5735.3 B=0.0519 M=30.5
# Base ('20557', 'Machos', 'ROSS', 'Convencional 3') -> A=5693.2 B=0.0515 M=31.7
# Base ('20557', 'Mistos', 'COBB', 'Convencional 3') -> A=5686.4 B=0.0495 M=32.8
# Base ('20557', 'Mistos', 'ROSS', 'Convencional 3') -> A=5605.0 B=0.0481 M=32.8
# Base ('20835', 'Fêmeas', 'COBB', 'Convencional 2 -') -> A=6000.0 B=0.0447 M=35.2
# Base ('20835', 'Fêmeas', 'ROSS', 'Convencional 2 -') -> A=4978.7 B=0.0491 M=31.9
# Base ('20835', 'Machos', 'ROSS', 'Convencional 2 -') -> A=3427.6 B=0.0748 M=23.0
# Base ('20835', 'Mistos', 'COBB', 'Convencional 2 -') -> A=5804.3 B=0.0473 M=33.9
# Base ('20835', 'Mistos', 'ROSS', 'Convencional 2 -') -> A=5942.9 B=0.0443 M=34.9
# Base ('20840', 'Fêmeas', 'COBB', 'Convencional 1 +') -> A=5678.5 B=0.0459 M=33.2
# Base ('20840', 'Machos', 'COBB', 'Convencional 1 +') -> A=5275.1 B=0.0549 M=29.6
# Base ('20840', 'Machos', 'ROSS', 'Convencional 1 +') -> A=5438.9 B=0.0506 M=31.9
# Base ('20840', 'Mistos', 'COBB', 'Convencional 1 +') -> A=6000.0 B=0.0481 M=32.9
# Base ('20840', 'Mistos', 'ROSS', 'Convencional 1 +') -> A=5949.4 B=0.0453 M=36.6
# Base ('21050', 'Fêmeas', 'COBB', 'Convencional 3') -> A=4841.8 B=0.0504 M=30.5
# Base ('21050', 'Fêmeas', 'ROSS', 'Convencional 3') -> A=4960.1 B=0.0477 M=31.7
# Base ('21050', 'Machos', 'ROSS', 'Convencional 3') -> A=6000.0 B=0.0478 M=33.6
# Base ('21050', 'Mistos', 'COBB', 'Convencional 3') -> A=3786.3 B=0.0661 M=25.3
# Base ('21050', 'Mistos', 'ROSS', 'Convencional 3') -> A=5369.8 B=0.0493 M=33.0
# Base ('21272', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5453.1 B=0.0473 M=33.2
# Base ('21272', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=5801.3 B=0.0438 M=34.9
# Base ('21272', 'Machos', 'COBB', 'Convencional 2') -> A=5549.5 B=0.0571 M=30.1
# Base ('21272', 'Machos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0524 M=32.3
# Base ('21272', 'Mistos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0470 M=34.8
# Base ('21272', 'Mistos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0486 M=34.8
# Base ('21375', 'Fêmeas', 'COBB', 'Convencional 1') -> A=5672.0 B=0.0437 M=34.8
# Base ('21375', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=4328.2 B=0.0533 M=29.7
# Base ('21375', 'Machos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0452 M=35.3
# Base ('21375', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0431 M=36.0
# Base ('21375', 'Mistos', 'ROSS', 'Convencional 1') -> A=4605.8 B=0.0491 M=30.9
# Base ('21550', 'Fêmeas', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0451 M=34.5
# Base ('21550', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0449 M=35.4
# Base ('21554', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5747.4 B=0.0433 M=34.2
# Base ('21554', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=4529.4 B=0.0527 M=30.9
# Base ('21554', 'Machos', 'ROSS', 'Convencional 2') -> A=4591.7 B=0.0521 M=29.7
# Base ('21554', 'Mistos', 'COBB', 'Convencional 2') -> A=5467.2 B=0.0489 M=32.0
# Base ('21554', 'Mistos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0442 M=37.6
# Base ('21715', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5186.8 B=0.0466 M=32.6
# Base ('21715', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0390 M=38.1
# Base ('21715', 'Machos', 'COBB', 'Convencional 2') -> A=4989.9 B=0.0551 M=29.1
# Base ('21715', 'Mistos', 'COBB', 'Convencional 2') -> A=5647.7 B=0.0487 M=32.4
# Base ('21715', 'Mistos', 'ROSS', 'Convencional 2') -> A=5695.7 B=0.0476 M=34.8
# Base ('22091', 'Fêmeas', 'COBB', 'Climatizado 2') -> A=4177.2 B=0.0623 M=26.4
# Base ('22091', 'Machos', 'COBB', 'Climatizado 2') -> A=5415.1 B=0.0540 M=30.0
# Base ('22091', 'Machos', 'ROSS', 'Climatizado 2') -> A=6000.0 B=0.0510 M=33.1
# Base ('22091', 'Mistos', 'COBB', 'Climatizado 2') -> A=3761.6 B=0.0686 M=24.7
# Base ('22091', 'Mistos', 'ROSS', 'Climatizado 2') -> A=5830.3 B=0.0470 M=33.5
# Base ('22273', 'Fêmeas', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0440 M=35.0
# Base ('22273', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=3955.2 B=0.0589 M=26.9
# Base ('22273', 'Machos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0501 M=32.5
# Base ('22273', 'Mistos', 'ROSS', 'Convencional 1') -> A=4760.6 B=0.0533 M=30.0
# Base ('22657', 'Fêmeas', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0443 M=35.4
# Base ('22657', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=5432.5 B=0.0459 M=33.9
# Base ('22657', 'Machos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0495 M=33.5
# Base ('22657', 'Machos', 'ROSS', 'Convencional 2') -> A=4519.7 B=0.0573 M=28.1
# Base ('22657', 'Mistos', 'ROSS', 'Convencional 2') -> A=5476.3 B=0.0477 M=35.0
# Base ('22697', 'Fêmeas', 'COBB', 'Convencional 2') -> A=3049.1 B=0.0710 M=22.4
# Base ('22697', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=3872.7 B=0.0594 M=28.6
# Base ('22697', 'Machos', 'ROSS', 'Convencional 2') -> A=4711.7 B=0.0558 M=29.6
# Base ('22697', 'Mistos', 'COBB', 'Convencional 2') -> A=3467.4 B=0.0654 M=25.5
# Base ('22697', 'Mistos', 'ROSS', 'Convencional 2') -> A=5655.1 B=0.0396 M=39.2
# Base ('22711', 'Fêmeas', 'COBB', 'Convencional 1') -> A=5842.6 B=0.0449 M=34.5
# Base ('22711', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=3644.5 B=0.0558 M=27.2
# Base ('22711', 'Machos', 'COBB', 'Convencional 1') -> A=4077.6 B=0.0680 M=25.0
# Base ('22711', 'Machos', 'ROSS', 'Convencional 1') -> A=5626.9 B=0.0481 M=33.5
# Base ('22711', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0493 M=33.4
# Base ('22711', 'Mistos', 'ROSS', 'Convencional 1') -> A=4868.5 B=0.0531 M=31.6
# Base ('22793', 'Fêmeas', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0467 M=34.1
# Base ('22793', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=5627.0 B=0.0456 M=34.3
# Base ('22793', 'Machos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0479 M=33.5
# Base ('22793', 'Mistos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0472 M=34.4
# Base ('22793', 'Mistos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0465 M=35.8
# Base ('22951', 'Fêmeas', 'COBB', 'Climatizado 2') -> A=5492.6 B=0.0460 M=33.5
# Base ('22951', 'Fêmeas', 'COBB', 'Convencional 1') -> A=5014.7 B=0.0489 M=31.8
# Base ('22951', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=4451.2 B=0.0507 M=30.9
# Base ('22951', 'Machos', 'COBB', 'Climatizado 2') -> A=6000.0 B=0.0490 M=33.0
# Base ('22951', 'Machos', 'ROSS', 'Climatizado 2') -> A=3772.7 B=0.0630 M=25.8
# Base ('22951', 'Mistos', 'COBB', 'Climatizado 2') -> A=4226.8 B=0.0621 M=26.8
# Base ('22951', 'Mistos', 'COBB', 'Convencional 1') -> A=5778.2 B=0.0454 M=34.6
# Base ('22951', 'Mistos', 'ROSS', 'Convencional 1') -> A=5124.0 B=0.0503 M=31.0
# Base ('22955', 'Fêmeas', 'COBB', 'Convencional 3') -> A=4408.1 B=0.0540 M=28.3
# Base ('22955', 'Fêmeas', 'ROSS', 'Convencional 3') -> A=5008.7 B=0.0485 M=30.5
# Base ('22955', 'Machos', 'COBB', 'Climatizado 2') -> A=4536.8 B=0.0630 M=26.2
# Base ('22955', 'Machos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0524 M=31.6
# Base ('22955', 'Machos', 'ROSS', 'Convencional 3') -> A=6000.0 B=0.0478 M=33.0
# Base ('22955', 'Mistos', 'COBB', 'Convencional 3') -> A=4736.1 B=0.0530 M=30.6
# Base ('22955', 'Mistos', 'ROSS', 'Convencional 3') -> A=5809.2 B=0.0497 M=33.8
# Base ('23012', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4325.9 B=0.0542 M=28.2
# Base ('23012', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=4882.5 B=0.0480 M=32.2
# Base ('23012', 'Mistos', 'COBB', 'Convencional 1') -> A=5318.1 B=0.0494 M=32.6
# Base ('23012', 'Mistos', 'ROSS', 'Convencional 1') -> A=6000.0 B=0.0457 M=34.9
# Base ('23133', 'Fêmeas', 'COBB', 'Convencional 3') -> A=5339.3 B=0.0462 M=32.7
# Base ('23133', 'Fêmeas', 'ROSS', 'Convencional 3') -> A=5811.6 B=0.0439 M=35.0
# Base ('23133', 'Machos', 'COBB', 'Convencional 3') -> A=4340.2 B=0.0605 M=26.3
# Base ('23133', 'Machos', 'ROSS', 'Convencional 3') -> A=6000.0 B=0.0481 M=33.3
# Base ('23133', 'Mistos', 'COBB', 'Convencional 3') -> A=5374.1 B=0.0492 M=32.4
# Base ('23133', 'Mistos', 'ROSS', 'Convencional 3') -> A=4676.1 B=0.0543 M=29.6
# Base ('23151', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5132.0 B=0.0470 M=32.3
# Base ('23151', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=3678.6 B=0.0579 M=26.4
# Base ('23151', 'Machos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0497 M=32.1
# Base ('23151', 'Machos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0440 M=36.1
# Base ('23151', 'Mistos', 'COBB', 'Convencional 2') -> A=5932.2 B=0.0428 M=36.4
# Base ('23151', 'Mistos', 'ROSS', 'Convencional 2') -> A=4283.3 B=0.0516 M=31.1
# Base ('23518', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5488.6 B=0.0469 M=32.4
# Base ('23518', 'Machos', 'ROSS', 'Convencional 2') -> A=5712.2 B=0.0519 M=31.4
# Base ('23518', 'Mistos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0477 M=33.3
# Base ('23518', 'Mistos', 'ROSS', 'Convencional 2') -> A=4962.0 B=0.0518 M=29.9
# Base ('23590', 'Fêmeas', 'COBB', 'Convencional 1') -> A=5795.2 B=0.0450 M=34.8
# Base ('23590', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=4333.7 B=0.0494 M=32.1
# Base ('23590', 'Machos', 'COBB', 'Convencional 1') -> A=5752.7 B=0.0499 M=32.9
# Base ('23590', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0449 M=35.5
# Base ('23670', 'Fêmeas', 'COBB', 'Climatizado 1') -> A=5036.4 B=0.0495 M=30.5
# Base ('23670', 'Fêmeas', 'COBB', 'Convencional 3') -> A=5055.8 B=0.0505 M=30.3
# Base ('23670', 'Fêmeas', 'ROSS', 'Climatizado 1') -> A=4177.4 B=0.0558 M=27.6
# Base ('23670', 'Fêmeas', 'ROSS', 'Convencional 3') -> A=4135.2 B=0.0558 M=27.7
# Base ('23670', 'Machos', 'COBB', 'Climatizado 1') -> A=6000.0 B=0.0513 M=31.5
# Base ('23670', 'Machos', 'COBB', 'Convencional 3') -> A=5617.9 B=0.0530 M=29.9
# Base ('23670', 'Mistos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0478 M=33.4
# Base ('23670', 'Mistos', 'ROSS', 'Convencional 3') -> A=4603.5 B=0.0556 M=29.8
# Base ('23715', 'Fêmeas', 'COBB', 'Convencional 2 +') -> A=5099.1 B=0.0515 M=30.5
# Base ('23715', 'Fêmeas', 'ROSS', 'Convencional 2 +') -> A=4771.7 B=0.0454 M=32.7
# Base ('23715', 'Machos', 'COBB', 'Climatizado 2') -> A=5430.6 B=0.0542 M=29.5
# Base ('23715', 'Machos', 'COBB', 'Convencional 2 +') -> A=5734.8 B=0.0468 M=32.4
# Base ('23715', 'Machos', 'ROSS', 'Climatizado 2') -> A=5394.7 B=0.0539 M=29.9
# Base ('23715', 'Machos', 'ROSS', 'Convencional 2 +') -> A=4172.1 B=0.0644 M=26.1
# Base ('23715', 'Mistos', 'COBB', 'Climatizado 2') -> A=4416.2 B=0.0592 M=28.6
# Base ('23715', 'Mistos', 'COBB', 'Convencional 2 +') -> A=4767.4 B=0.0511 M=30.4
# Base ('23715', 'Mistos', 'ROSS', 'Climatizado 2') -> A=3797.6 B=0.0595 M=27.8
# Base ('23730', 'Fêmeas', 'COBB', 'Convencional 1') -> A=5205.8 B=0.0485 M=32.1
# Base ('23730', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=5336.5 B=0.0468 M=33.7
# Base ('23730', 'Machos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0524 M=32.6
# Base ('23730', 'Machos', 'ROSS', 'Convencional 1') -> A=6000.0 B=0.0539 M=33.8
# Base ('23730', 'Mistos', 'COBB', 'Convencional 1') -> A=5688.7 B=0.0468 M=34.0
# Base ('23730', 'Mistos', 'ROSS', 'Convencional 1') -> A=4210.7 B=0.0518 M=30.4
# Base ('23955', 'Fêmeas', 'COBB', 'Climatizado 1') -> A=5185.1 B=0.0485 M=31.8
# Base ('23955', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5749.1 B=0.0465 M=34.0
# Base ('23955', 'Machos', 'COBB', 'Climatizado 1') -> A=5809.9 B=0.0500 M=32.2
# Base ('23955', 'Machos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0479 M=32.8
# Base ('23955', 'Machos', 'ROSS', 'Climatizado 1') -> A=6000.0 B=0.0471 M=34.0
# Base ('23955', 'Machos', 'ROSS', 'Convencional 2') -> A=5266.2 B=0.0538 M=30.0
# Base ('23955', 'Mistos', 'COBB', 'Climatizado 1') -> A=5752.6 B=0.0470 M=34.0
# Base ('23955', 'Mistos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0485 M=34.4
# Base ('23955', 'Mistos', 'ROSS', 'Climatizado 1') -> A=5886.9 B=0.0468 M=34.4
# Base ('23955', 'Mistos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0470 M=35.1
# Base ('23960', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5481.2 B=0.0482 M=31.9
# Base ('23960', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=4816.4 B=0.0532 M=29.9
# Base ('23960', 'Mistos', 'COBB', 'Convencional 2') -> A=5570.5 B=0.0481 M=33.1
# Base ('23960', 'Mistos', 'ROSS', 'Convencional 2') -> A=5162.8 B=0.0512 M=30.8
# Base ('23960', 'Sexados', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0437 M=35.3
# Base ('23992', 'Fêmeas', 'COBB', 'Convencional 1 +') -> A=4565.9 B=0.0555 M=28.1
# Base ('23992', 'Fêmeas', 'ROSS', 'Convencional 1 +') -> A=5170.3 B=0.0468 M=33.1
# Base ('23992', 'Machos', 'COBB', 'Convencional 1 +') -> A=6000.0 B=0.0494 M=32.3
# Base ('23992', 'Machos', 'ROSS', 'Convencional 1 +') -> A=6000.0 B=0.0494 M=33.6
# Base ('23992', 'Mistos', 'COBB', 'Convencional 1 +') -> A=5743.9 B=0.0476 M=33.5
# Base ('23992', 'Mistos', 'ROSS', 'Convencional 1 +') -> A=6000.0 B=0.0465 M=34.4
# Base ('24035', 'Fêmeas', 'COBB', 'Convencional 3') -> A=4502.6 B=0.0499 M=30.4
# Base ('24035', 'Fêmeas', 'ROSS', 'Convencional 3') -> A=6000.0 B=0.0397 M=37.8
# Base ('24035', 'Machos', 'COBB', 'Convencional 3') -> A=4297.7 B=0.0596 M=27.1
# Base ('24035', 'Mistos', 'COBB', 'Convencional 3') -> A=4570.0 B=0.0537 M=29.6
# Base ('24035', 'Mistos', 'ROSS', 'Convencional 3') -> A=4458.2 B=0.0514 M=31.1
# Base ('24172', 'Fêmeas', 'COBB', 'Climatizado 1') -> A=4990.5 B=0.0528 M=29.6
# Base ('24172', 'Fêmeas', 'ROSS', 'Climatizado 1') -> A=4690.6 B=0.0526 M=29.5
# Base ('24172', 'Machos', 'COBB', 'Climatizado 1') -> A=4474.2 B=0.0630 M=25.9
# Base ('24172', 'Machos', 'COBB', 'Convencional 1') -> A=5264.5 B=0.0533 M=30.3
# Base ('24172', 'Mistos', 'COBB', 'Climatizado 1') -> A=5217.3 B=0.0544 M=29.9
# Base ('24235', 'Fêmeas', 'COBB', 'Convencional 2') -> A=4244.9 B=0.0544 M=29.0
# Base ('24235', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0433 M=37.8
# Base ('24235', 'Machos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0500 M=34.5
# Base ('24235', 'Mistos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0516 M=33.6
# Base ('24235', 'Mistos', 'HUBBARD', 'Convencional 2') -> A=4255.6 B=0.0544 M=29.8
# Base ('24235', 'Mistos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0426 M=37.6
# Base ('24274', 'Fêmeas', 'COBB', 'Convencional 2') -> A=4774.6 B=0.0514 M=29.7
# Base ('24274', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0388 M=39.5
# Base ('24392', 'Fêmeas', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0436 M=35.0
# Base ('24392', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=5846.4 B=0.0435 M=35.7
# Base ('24392', 'Machos', 'COBB', 'Convencional 1') -> A=5459.9 B=0.0525 M=30.6
# Base ('24392', 'Machos', 'ROSS', 'Convencional 1') -> A=6000.0 B=0.0476 M=34.3
# Base ('24392', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0488 M=33.3
# Base ('24392', 'Mistos', 'ROSS', 'Convencional 1') -> A=5911.1 B=0.0425 M=35.3
# Base ('24739', 'Fêmeas', 'COBB', 'Convencional 1') -> A=3678.2 B=0.0652 M=24.2
# Base ('24739', 'Fêmeas', 'COBB', 'Semi-climatizado') -> A=2866.7 B=0.0719 M=20.3
# Base ('24739', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=6000.0 B=0.0471 M=34.2
# Base ('24739', 'Machos', 'COBB', 'Semi-climatizado') -> A=4616.2 B=0.0627 M=26.0
# Base ('24739', 'Machos', 'ROSS', 'Semi-climatizado') -> A=4735.9 B=0.0609 M=27.2
# Base ('24739', 'Mistos', 'COBB', 'Convencional 1') -> A=5724.0 B=0.0496 M=31.9
# Base ('24739', 'Mistos', 'COBB', 'Semi-climatizado') -> A=3047.6 B=0.0837 M=23.0
# Base ('24739', 'Mistos', 'ROSS', 'Convencional 1') -> A=4156.0 B=0.0551 M=27.8
# Base ('24739', 'Mistos', 'ROSS', 'Semi-climatizado') -> A=4998.6 B=0.0518 M=31.2
# Base ('24793', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4633.1 B=0.0520 M=29.9
# Base ('24793', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=4313.7 B=0.0530 M=29.2
# Base ('24793', 'Machos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0481 M=33.7
# Base ('24793', 'Mistos', 'COBB', 'Convencional 1') -> A=4897.9 B=0.0531 M=29.6
# Base ('24793', 'Mistos', 'ROSS', 'Convencional 1') -> A=4791.4 B=0.0523 M=30.0
# Base ('25330', 'Fêmeas', 'COBB', 'Convencional 2 -') -> A=5607.2 B=0.0455 M=34.6
# Base ('25330', 'Fêmeas', 'ROSS', 'Convencional 2 -') -> A=5366.7 B=0.0435 M=36.5
# Base ('25330', 'Machos', 'COBB', 'Convencional 2 -') -> A=4131.4 B=0.0632 M=27.3
# Base ('25330', 'Machos', 'ROSS', 'Convencional 2 -') -> A=4493.4 B=0.0597 M=27.7
# Base ('25330', 'Mistos', 'COBB', 'Convencional 2 -') -> A=5228.8 B=0.0492 M=32.5
# Base ('25330', 'Mistos', 'ROSS', 'Convencional 2 -') -> A=6000.0 B=0.0429 M=37.9
# Base ('25930', 'Fêmeas', 'COBB', 'Convencional 1 +') -> A=4753.8 B=0.0516 M=29.5
# Base ('25930', 'Fêmeas', 'ROSS', 'Convencional 1 +') -> A=5488.0 B=0.0493 M=34.1
# Base ('25930', 'Machos', 'ROSS', 'Convencional 1 +') -> A=5235.0 B=0.0528 M=30.0
# Base ('25930', 'Mistos', 'COBB', 'Convencional 1 +') -> A=6000.0 B=0.0461 M=35.0
# Base ('25930', 'Mistos', 'ROSS', 'Convencional 1 +') -> A=5050.8 B=0.0485 M=32.3
# Base ('25953', 'Fêmeas', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0429 M=36.5
# Base ('25953', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=4867.6 B=0.0476 M=33.5
# Base ('25953', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0464 M=35.5
# Base ('25953', 'Mistos', 'ROSS', 'Convencional 1') -> A=6000.0 B=0.0454 M=35.5
# Base ('26070', 'Fêmeas', 'COBB', 'Convencional 1') -> A=5264.6 B=0.0469 M=32.1
# Base ('26070', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=5757.6 B=0.0430 M=34.8
# Base ('26070', 'Mistos', 'COBB', 'Convencional 1') -> A=5393.7 B=0.0491 M=32.1
# Base ('26070', 'Mistos', 'ROSS', 'Convencional 1') -> A=6000.0 B=0.0494 M=33.7
# Base ('26110', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5294.1 B=0.0471 M=32.5
# Base ('26110', 'Fêmeas', 'HUBBARD', 'Convencional 2') -> A=6000.0 B=0.0449 M=35.4
# Base ('26110', 'Machos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0498 M=32.9
# Base ('26110', 'Machos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0510 M=33.7
# Base ('26110', 'Mistos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0458 M=35.5
# Base ('26110', 'Mistos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0452 M=35.3
# Base ('26115', 'Fêmeas', 'COBB', 'Convencional 2') -> A=4536.6 B=0.0533 M=29.1
# Base ('26115', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=3591.8 B=0.0597 M=26.7
# Base ('26115', 'Machos', 'COBB', 'Convencional 2') -> A=4167.2 B=0.0651 M=25.7
# Base ('26115', 'Machos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0508 M=34.5
# Base ('26115', 'Mistos', 'COBB', 'Convencional 2') -> A=5254.9 B=0.0523 M=31.3
# Base ('26115', 'Mistos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0474 M=34.1
# Base ('26150', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4518.3 B=0.0544 M=28.9
# Base ('26150', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=4025.8 B=0.0555 M=28.5
# Base ('26150', 'Machos', 'ROSS', 'Convencional 1') -> A=4988.8 B=0.0523 M=30.2
# Base ('26150', 'Mistos', 'COBB', 'Convencional 1') -> A=4711.8 B=0.0519 M=30.3
# Base ('26290', 'Fêmeas', 'COBB', 'Convencional 1') -> A=5161.0 B=0.0463 M=32.6
# Base ('26290', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=5232.9 B=0.0438 M=34.5
# Base ('26290', 'Machos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0506 M=32.3
# Base ('26290', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0451 M=35.7
# Base ('26290', 'Mistos', 'ROSS', 'Convencional 1') -> A=4188.5 B=0.0514 M=30.8
# Base ('26995', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4338.0 B=0.0564 M=27.1
# Base ('26995', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=4960.5 B=0.0507 M=30.4
# Base ('26995', 'Machos', 'COBB', 'Convencional 1') -> A=5103.1 B=0.0537 M=30.6
# Base ('26995', 'Mistos', 'COBB', 'Convencional 1') -> A=5528.4 B=0.0477 M=33.1
# Base ('26995', 'Mistos', 'ROSS', 'Convencional 1') -> A=5244.4 B=0.0497 M=31.7
# Base ('27070', 'Fêmeas', 'COBB', 'Convencional 1') -> A=5168.9 B=0.0488 M=32.9
# Base ('27070', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0430 M=37.0
# Base ('27070', 'Mistos', 'ROSS', 'Convencional 1') -> A=6000.0 B=0.0447 M=37.3
# Base ('27136', 'Fêmeas', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0467 M=36.0
# Base ('27136', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=4543.5 B=0.0498 M=31.9
# Base ('27136', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0442 M=37.8
# Base ('27138', 'Fêmeas', 'COBB', 'Convencional 1') -> A=5449.0 B=0.0437 M=35.2
# Falha curva-base para chave: ('27138', 'Fêmeas', 'ROSS', 'Convencional 1')
# Base ('27138', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0444 M=37.2
# Base ('27331', 'Fêmeas', 'COBB', 'Climatizado 2') -> A=5788.5 B=0.0460 M=33.3
# Base ('27331', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5296.9 B=0.0469 M=32.5
# Base ('27331', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=4957.9 B=0.0497 M=31.4
# Base ('27331', 'Machos', 'COBB', 'Climatizado 2') -> A=4788.4 B=0.0600 M=27.5
# Base ('27331', 'Machos', 'COBB', 'Convencional 2') -> A=5376.7 B=0.0499 M=31.7
# Base ('27331', 'Mistos', 'COBB', 'Convencional 2') -> A=5169.9 B=0.0505 M=31.1
# Base ('27331', 'Mistos', 'ROSS', 'Climatizado 2') -> A=4702.6 B=0.0567 M=28.2
# Base ('27415', 'Machos', 'COBB', 'Climatizado 1') -> A=6000.0 B=0.0547 M=31.5
# Base ('27415', 'Machos', 'COBB', 'Climatizado 2') -> A=4721.7 B=0.0600 M=27.4
# Base ('27415', 'Machos', 'ROSS', 'Climatizado 2') -> A=6000.0 B=0.0513 M=32.6
# Base ('27415', 'Mistos', 'COBB', 'Climatizado 2') -> A=4095.3 B=0.0686 M=24.8
# Base ('27415', 'Sexados', 'COBB', 'Climatizado 2') -> A=4687.9 B=0.0504 M=30.0
# Base ('27530', 'Fêmeas', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0406 M=37.2
# Base ('27530', 'Mistos', 'ROSS', 'Convencional 1') -> A=3195.1 B=0.0645 M=25.4
# Base ('27796', 'Fêmeas', 'COBB', 'Convencional 3') -> A=4388.8 B=0.0529 M=29.5
# Base ('27796', 'Fêmeas', 'ROSS', 'Convencional 3') -> A=6000.0 B=0.0441 M=35.8
# Base ('27796', 'Machos', 'ROSS', 'Convencional 3') -> A=5121.3 B=0.0508 M=30.9
# Base ('27796', 'Mistos', 'COBB', 'Convencional 3') -> A=5890.8 B=0.0471 M=33.2
# Base ('27796', 'Mistos', 'ROSS', 'Convencional 3') -> A=5544.6 B=0.0443 M=35.4
# Base ('27812', 'Fêmeas', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0422 M=36.1
# Base ('27812', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=4093.3 B=0.0612 M=26.3
# Base ('27812', 'Machos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0479 M=33.0
# Base ('27812', 'Machos', 'ROSS', 'Convencional 2') -> A=4853.8 B=0.0549 M=29.0
# Base ('27812', 'Mistos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0434 M=36.3
# Base ('27812', 'Mistos', 'ROSS', 'Convencional 2') -> A=5064.0 B=0.0495 M=33.2
# Base ('27931', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4324.5 B=0.0519 M=29.0
# Base ('27931', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=3684.1 B=0.0578 M=27.2
# Base ('27931', 'Mistos', 'COBB', 'Convencional 1') -> A=3675.6 B=0.0644 M=25.9
# Base ('27931', 'Mistos', 'ROSS', 'Convencional 1') -> A=6000.0 B=0.0438 M=35.4
# Base ('27933', 'Fêmeas', 'COBB', 'Convencional 1 +') -> A=5694.4 B=0.0440 M=34.2
# Base ('27933', 'Machos', 'COBB', 'Convencional 1 +') -> A=4415.0 B=0.0600 M=26.2
# Base ('27933', 'Machos', 'ROSS', 'Convencional 1 +') -> A=5020.5 B=0.0526 M=30.7
# Base ('27933', 'Mistos', 'COBB', 'Convencional 1 +') -> A=5076.7 B=0.0514 M=32.0
# Base ('27933', 'Mistos', 'ROSS', 'Convencional 1 +') -> A=6000.0 B=0.0442 M=36.7
# Base ('28112', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5848.8 B=0.0439 M=35.4
# Base ('28112', 'Mistos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0478 M=34.4
# Base ('28112', 'Mistos', 'ROSS', 'Convencional 2') -> A=5081.2 B=0.0506 M=32.4
# Base ('28870', 'Fêmeas', 'COBB', 'Convencional 3') -> A=3779.4 B=0.0595 M=25.7
# Base ('28870', 'Fêmeas', 'ROSS', 'Convencional 3') -> A=5997.5 B=0.0424 M=35.8
# Base ('28870', 'Machos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0499 M=32.8
# Base ('28870', 'Mistos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0458 M=35.2
# Base ('28870', 'Mistos', 'ROSS', 'Convencional 3') -> A=6000.0 B=0.0459 M=34.9
# Base ('28872', 'Fêmeas', 'COBB', 'Climatizado 2') -> A=5533.4 B=0.0458 M=33.3
# Base ('28872', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5451.6 B=0.0481 M=32.0
# Base ('28872', 'Fêmeas', 'COBB', 'Convencional 3') -> A=5647.7 B=0.0457 M=33.2
# Base ('28872', 'Machos', 'COBB', 'Climatizado 2') -> A=5376.9 B=0.0537 M=29.7
# Base ('28872', 'Machos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0520 M=30.8
# Base ('28872', 'Machos', 'COBB', 'Convencional 3') -> A=5594.7 B=0.0513 M=30.4
# Base ('28872', 'Machos', 'HUBBARD', 'Climatizado 2') -> A=6000.0 B=0.0476 M=33.1
# Base ('28872', 'Machos', 'ROSS', 'Climatizado 2') -> A=5484.4 B=0.0529 M=30.2
# Base ('28872', 'Mistos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0464 M=33.1
# Base ('28872', 'Mistos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0473 M=34.7
# Base ('28872', 'Mistos', 'ROSS', 'Climatizado 2') -> A=6000.0 B=0.0467 M=33.6
# Base ('28872', 'Mistos', 'ROSS', 'Convencional 2') -> A=5185.5 B=0.0472 M=33.9
# Base ('28872', 'Mistos', 'ROSS', 'Convencional 3') -> A=4933.8 B=0.0518 M=32.4
# Base ('29091', 'Fêmeas', 'COBB', 'Convencional 1') -> A=5083.6 B=0.0465 M=32.9
# Base ('29091', 'Machos', 'ROSS', 'Convencional 1') -> A=5157.3 B=0.0525 M=30.7
# Base ('29091', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0462 M=35.5
# Base ('29095', 'Fêmeas', 'COBB', 'Convencional 2') -> A=4971.6 B=0.0486 M=29.9
# Base ('29095', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=3583.7 B=0.0644 M=25.0
# Base ('29095', 'Machos', 'COBB', 'Convencional 2') -> A=5772.0 B=0.0501 M=31.8
# Base ('29095', 'Machos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0487 M=32.7
# Base ('29095', 'Mistos', 'COBB', 'Convencional 2') -> A=3828.0 B=0.0637 M=24.8
# Base ('29095', 'Mistos', 'ROSS', 'Convencional 2') -> A=3797.3 B=0.0645 M=25.1
# Base ('29531', 'Fêmeas', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0434 M=35.8
# Base ('29531', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=5213.6 B=0.0468 M=32.8
# Base ('29531', 'Machos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0508 M=31.6
# Base ('29531', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0460 M=34.5
# Base ('29531', 'Mistos', 'ROSS', 'Convencional 1') -> A=5731.1 B=0.0461 M=34.9
# Base ('29775', 'Fêmeas', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0423 M=36.3
# Base ('29775', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=5041.4 B=0.0471 M=33.4
# Base ('29775', 'Mistos', 'COBB', 'Convencional 1') -> A=5323.6 B=0.0482 M=32.9
# Base ('29775', 'Mistos', 'ROSS', 'Convencional 1') -> A=4467.5 B=0.0550 M=31.6
# Base ('29854', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4333.3 B=0.0552 M=27.7
# Base ('29854', 'Fêmeas', 'HUBBARD', 'Convencional 1') -> A=5981.2 B=0.0411 M=36.5
# Base ('29854', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=3217.2 B=0.0677 M=22.9
# Base ('29854', 'Machos', 'COBB', 'Convencional 1') -> A=3147.2 B=0.0892 M=20.8
# Base ('29854', 'Machos', 'ROSS', 'Convencional 1') -> A=5580.9 B=0.0499 M=31.6
# Base ('29854', 'Mistos', 'COBB', 'Convencional 1') -> A=4875.1 B=0.0559 M=30.0
# Base ('29854', 'Mistos', 'ROSS', 'Convencional 1') -> A=5409.8 B=0.0515 M=31.7
# Base ('30030', 'Fêmeas', 'COBB', 'Climatizado 2') -> A=5851.9 B=0.0460 M=33.8
# Base ('30030', 'Fêmeas', 'COBB', 'Convencional 3') -> A=4658.8 B=0.0532 M=29.4
# Base ('30030', 'Machos', 'COBB', 'Climatizado 2') -> A=5230.4 B=0.0570 M=28.3
# Base ('30030', 'Machos', 'COBB', 'Convencional 3') -> A=5767.4 B=0.0537 M=30.7
# Base ('30030', 'Machos', 'ROSS', 'Climatizado 2') -> A=6000.0 B=0.0514 M=31.8
# Base ('30030', 'Machos', 'ROSS', 'Convencional 3') -> A=5466.8 B=0.0509 M=31.7
# Base ('30030', 'Mistos', 'COBB', 'Climatizado 2') -> A=5717.0 B=0.0487 M=32.7
# Base ('30030', 'Mistos', 'COBB', 'Convencional 3') -> A=4414.4 B=0.0590 M=28.6
# Base ('30030', 'Mistos', 'ROSS', 'Climatizado 2') -> A=4420.9 B=0.0633 M=26.6
# Base ('30030', 'Mistos', 'ROSS', 'Convencional 3') -> A=4649.4 B=0.0575 M=28.7
# Base ('30410', 'Fêmeas', 'COBB', 'Convencional 3') -> A=5646.2 B=0.0460 M=34.7
# Base ('30410', 'Fêmeas', 'HUBBARD', 'Convencional 3') -> A=5225.1 B=0.0457 M=34.0
# Base ('30410', 'Machos', 'COBB', 'Convencional 3') -> A=5054.0 B=0.0578 M=28.7
# Base ('30410', 'Machos', 'ROSS', 'Convencional 3') -> A=5651.4 B=0.0503 M=32.9
# Base ('30410', 'Mistos', 'COBB', 'Convencional 3') -> A=5545.6 B=0.0500 M=33.6
# Base ('30412', 'Fêmeas', 'COBB', 'Convencional 2') -> A=4812.3 B=0.0485 M=30.7
# Base ('30412', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=4945.4 B=0.0460 M=33.5
# Base ('30412', 'Machos', 'COBB', 'Convencional 2') -> A=4835.5 B=0.0539 M=28.6
# Base ('30412', 'Mistos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0454 M=34.5
# Base ('30412', 'Mistos', 'ROSS', 'Convencional 2') -> A=3633.9 B=0.0634 M=25.5
# Base ('30653', 'Fêmeas', 'COBB', 'Climatizado 2') -> A=5972.5 B=0.0461 M=33.9
# Base ('30653', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5130.5 B=0.0479 M=32.1
# Base ('30653', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=4727.3 B=0.0495 M=31.1
# Base ('30653', 'Machos', 'COBB', 'Climatizado 2') -> A=4957.9 B=0.0577 M=28.5
# Base ('30653', 'Machos', 'COBB', 'Convencional 2') -> A=4404.6 B=0.0598 M=27.3
# Base ('30653', 'Machos', 'ROSS', 'Climatizado 2') -> A=5668.3 B=0.0505 M=31.8
# Base ('30653', 'Machos', 'ROSS', 'Convencional 2') -> A=5402.8 B=0.0527 M=31.8
# Base ('30653', 'Mistos', 'COBB', 'Climatizado 2') -> A=5038.6 B=0.0534 M=29.8
# Base ('30653', 'Mistos', 'COBB', 'Convencional 2') -> A=5098.7 B=0.0539 M=30.0
# Base ('30653', 'Mistos', 'ROSS', 'Climatizado 2') -> A=6000.0 B=0.0477 M=33.1
# Base ('30653', 'Mistos', 'ROSS', 'Convencional 2') -> A=4399.3 B=0.0563 M=29.3
# Base ('30676', 'Fêmeas', 'COBB', 'Convencional 1 +') -> A=6000.0 B=0.0425 M=36.3
# Base ('30676', 'Machos', 'COBB', 'Convencional 1 +') -> A=6000.0 B=0.0493 M=33.4
# Base ('30730', 'Fêmeas', 'COBB', 'Convencional 2') -> A=4716.0 B=0.0505 M=30.3
# Base ('30730', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=4911.0 B=0.0485 M=32.0
# Base ('30730', 'Machos', 'COBB', 'Convencional 2') -> A=4697.2 B=0.0596 M=27.0
# Base ('30730', 'Machos', 'ROSS', 'Convencional 2') -> A=5428.4 B=0.0498 M=32.2
# Base ('30730', 'Mistos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0465 M=33.7
# Base ('30730', 'Mistos', 'ROSS', 'Convencional 2') -> A=4853.8 B=0.0537 M=30.4
# Base ('30730', 'Sexados', 'COBB', 'Convencional 2') -> A=5451.6 B=0.0497 M=30.7
# Base ('30750', 'Fêmeas', 'COBB', 'Convencional 3') -> A=5497.8 B=0.0457 M=33.4
# Base ('30750', 'Machos', 'COBB', 'Convencional 3') -> A=5975.3 B=0.0470 M=34.2
# Base ('30750', 'Machos', 'ROSS', 'Convencional 3') -> A=5929.7 B=0.0448 M=36.6
# Base ('30750', 'Mistos', 'COBB', 'Convencional 3') -> A=4807.1 B=0.0537 M=29.5
# Base ('30750', 'Mistos', 'ROSS', 'Convencional 3') -> A=4601.8 B=0.0528 M=29.8
# Base ('30893', 'Fêmeas', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0437 M=34.7
# Base ('30893', 'Machos', 'COBB', 'Convencional 2') -> A=5933.7 B=0.0502 M=32.1
# Base ('30893', 'Machos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0497 M=33.0
# Base ('30893', 'Mistos', 'COBB', 'Convencional 2') -> A=5820.6 B=0.0458 M=34.7
# Base ('30893', 'Mistos', 'ROSS', 'Convencional 2') -> A=5398.8 B=0.0494 M=33.3
# Base ('31310', 'Fêmeas', 'COBB', 'Convencional 3') -> A=4765.3 B=0.0507 M=30.1
# Base ('31310', 'Fêmeas', 'ROSS', 'Convencional 3') -> A=5040.6 B=0.0466 M=33.4
# Base ('31310', 'Machos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0528 M=31.5
# Base ('31310', 'Mistos', 'COBB', 'Convencional 3') -> A=4976.6 B=0.0556 M=30.3
# Base ('31310', 'Mistos', 'ROSS', 'Convencional 3') -> A=5291.6 B=0.0497 M=33.7
# Base ('31311', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5043.5 B=0.0503 M=30.9
# Base ('31311', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0406 M=37.7
# Base ('31311', 'Machos', 'COBB', 'Convencional 2') -> A=5661.9 B=0.0517 M=32.3
# Base ('31311', 'Machos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0490 M=34.9
# Base ('31311', 'Mistos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0486 M=35.2
# Base ('31412', 'Fêmeas', 'COBB', 'Climatizado 2') -> A=4286.2 B=0.0596 M=27.1
# Base ('31412', 'Fêmeas', 'COBB', 'Convencional 3') -> A=5050.9 B=0.0494 M=31.1
# Base ('31412', 'Fêmeas', 'ROSS', 'Convencional 3') -> A=5111.1 B=0.0487 M=31.7
# Base ('31412', 'Machos', 'COBB', 'Climatizado 2') -> A=4937.2 B=0.0565 M=28.6
# Base ('31412', 'Machos', 'COBB', 'Convencional 3') -> A=5242.7 B=0.0518 M=30.4
# Base ('31412', 'Machos', 'ROSS', 'Climatizado 2') -> A=6000.0 B=0.0500 M=33.8
# Base ('31412', 'Machos', 'ROSS', 'Convencional 3') -> A=5640.3 B=0.0538 M=31.1
# Base ('31412', 'Mistos', 'COBB', 'Climatizado 2') -> A=5781.0 B=0.0488 M=33.7
# Base ('31412', 'Mistos', 'COBB', 'Convencional 3') -> A=5415.8 B=0.0511 M=32.0
# Base ('31412', 'Mistos', 'ROSS', 'Climatizado 2') -> A=5283.5 B=0.0519 M=31.1
# Base ('31412', 'Mistos', 'ROSS', 'Convencional 3') -> A=6000.0 B=0.0464 M=34.2
# Base ('31531', 'Fêmeas', 'COBB', 'Climatizado 2') -> A=6000.0 B=0.0463 M=35.0
# Base ('31531', 'Fêmeas', 'COBB', 'Convencional 2') -> A=4775.9 B=0.0516 M=30.2
# Base ('31531', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=4812.5 B=0.0476 M=32.7
# Base ('31531', 'Machos', 'COBB', 'Climatizado 2') -> A=5656.5 B=0.0511 M=31.4
# Base ('31531', 'Machos', 'COBB', 'Convencional 2') -> A=5095.0 B=0.0542 M=31.0
# Base ('31531', 'Machos', 'ROSS', 'Climatizado 2') -> A=4900.5 B=0.0555 M=29.2
# Base ('31531', 'Machos', 'ROSS', 'Convencional 2') -> A=4868.7 B=0.0507 M=31.3
# Base ('31531', 'Mistos', 'COBB', 'Climatizado 2') -> A=5545.3 B=0.0471 M=32.9
# Base ('31531', 'Mistos', 'COBB', 'Convencional 2') -> A=5681.2 B=0.0476 M=33.7
# Base ('31570', 'Fêmeas', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0447 M=35.6
# Base ('31570', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=3925.5 B=0.0540 M=28.7
# Base ('31570', 'Mistos', 'COBB', 'Convencional 1') -> A=4439.6 B=0.0486 M=31.3
# Base ('31570', 'Mistos', 'ROSS', 'Convencional 1') -> A=6000.0 B=0.0431 M=36.4
# Base ('31670', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5493.7 B=0.0446 M=33.8
# ...
# Base ('73605', 'Fêmeas', 'COBB', 'Convencional 2') -> A=4033.3 B=0.0588 M=26.6
# Base ('73605', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=4512.7 B=0.0495 M=30.6
# Base ('73605', 'Mistos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0417 M=37.0
# Base ('73605', 'Mistos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0452 M=35.1
# Base ('73834', 'Fêmeas', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0419 M=36.7
# Base ('73834', 'Mistos', 'COBB', 'Convencional 3') -> A=4738.6 B=0.0509 M=32.6
# Base ('73834', 'Mistos', 'ROSS', 'Convencional 3') -> A=6000.0 B=0.0459 M=34.8
# Base ('74009', 'Fêmeas', 'ROSS', 'Convencional 3') -> A=6000.0 B=0.0433 M=37.1
# Base ('74009', 'Machos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0483 M=33.6
# Base ('74009', 'Machos', 'ROSS', 'Convencional 3') -> A=6000.0 B=0.0504 M=32.8
# Base ('74009', 'Mistos', 'COBB', 'Convencional 3') -> A=5651.3 B=0.0455 M=35.4
# Base ('74777', 'Fêmeas', 'COBB', 'Convencional 3') -> A=5189.1 B=0.0481 M=32.3
# Base ('74777', 'Machos', 'COBB', 'Convencional 3') -> A=4929.4 B=0.0588 M=28.5
# Base ('74777', 'Mistos', 'COBB', 'Convencional 3') -> A=4883.7 B=0.0525 M=30.2
# Base ('74777', 'Mistos', 'ROSS', 'Convencional 3') -> A=4729.1 B=0.0530 M=29.6
# Base ('75028', 'Fêmeas', 'COBB', 'Convencional 2') -> A=3771.4 B=0.0617 M=25.2
# Base ('75028', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=5363.1 B=0.0510 M=33.2
# Base ('75028', 'Machos', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0492 M=32.3
# Base ('75028', 'Machos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0463 M=34.8
# Base ('75028', 'Mistos', 'COBB', 'Convencional 2') -> A=3869.6 B=0.0702 M=23.5
# Base ('75028', 'Mistos', 'ROSS', 'Convencional 2') -> A=5688.5 B=0.0479 M=32.9
# Base ('7531', 'Fêmeas', 'COBB', 'Convencional 3') -> A=4924.8 B=0.0507 M=30.0
# Base ('7531', 'Machos', 'COBB', 'Convencional 3') -> A=4463.2 B=0.0643 M=25.9
# Base ('7531', 'Machos', 'ROSS', 'Convencional 3') -> A=6000.0 B=0.0509 M=31.6
# Base ('7531', 'Mistos', 'ROSS', 'Convencional 3') -> A=5717.7 B=0.0475 M=33.5
# Base ('75546', 'Fêmeas', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0447 M=35.4
# Base ('75546', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0455 M=36.9
# Base ('75546', 'Mistos', 'COBB', 'Convencional 2') -> A=5588.9 B=0.0473 M=34.4
# Base ('75546', 'Mistos', 'ROSS', 'Convencional 2') -> A=5881.7 B=0.0467 M=35.2
# Base ('75665', 'Mistos', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0481 M=33.5
# Base ('77232', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5304.3 B=0.0455 M=33.7
# Base ('77232', 'Machos', 'COBB', 'Convencional 2') -> A=5378.0 B=0.0560 M=29.0
# Base ('77232', 'Mistos', 'ROSS', 'Convencional 2') -> A=5317.2 B=0.0491 M=33.3
# Base ('77436', 'Fêmeas', 'COBB', 'Climatizado 2') -> A=6000.0 B=0.0452 M=34.2
# Base ('77436', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5016.9 B=0.0511 M=30.7
# Base ('77436', 'Machos', 'COBB', 'Climatizado 2') -> A=5146.9 B=0.0607 M=27.7
# Falha curva-base para chave: ('77436', 'Machos', 'COBB', 'Convencional 2')
# Base ('77436', 'Mistos', 'COBB', 'Convencional 2') -> A=5176.7 B=0.0541 M=31.1
# Base ('77436', 'Mistos', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0496 M=32.7
# Base ('7770', 'Fêmeas', 'COBB', 'Convencional 3') -> A=5513.8 B=0.0459 M=33.4
# Base ('7770', 'Fêmeas', 'ROSS', 'Convencional 3') -> A=5363.7 B=0.0435 M=34.8
# Base ('7770', 'Machos', 'COBB', 'Climatizado 2') -> A=5436.8 B=0.0539 M=29.7
# Base ('7770', 'Machos', 'COBB', 'Convencional 3') -> A=5094.5 B=0.0545 M=29.8
# Base ('7770', 'Machos', 'ROSS', 'Climatizado 2') -> A=6000.0 B=0.0515 M=31.9
# Base ('7770', 'Mistos', 'COBB', 'Climatizado 2') -> A=5157.6 B=0.0489 M=31.7
# Base ('7770', 'Mistos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0487 M=34.2
# Base ('7770', 'Mistos', 'ROSS', 'Convencional 3') -> A=5403.8 B=0.0471 M=33.8
# Base ('7951', 'Fêmeas', 'COBB', 'Climatizado 2') -> A=4795.5 B=0.0516 M=30.3
# Base ('7951', 'Fêmeas', 'COBB', 'Convencional 1') -> A=5226.1 B=0.0483 M=31.5
# Base ('7951', 'Fêmeas', 'ROSS', 'Climatizado 2') -> A=4944.1 B=0.0486 M=31.0
# Base ('7951', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=5378.3 B=0.0462 M=33.9
# Base ('7951', 'Machos', 'COBB', 'Climatizado 2') -> A=4905.8 B=0.0598 M=27.7
# Base ('7951', 'Machos', 'COBB', 'Convencional 1') -> A=5696.9 B=0.0514 M=30.8
# Base ('7951', 'Machos', 'ROSS', 'Convencional 1') -> A=5207.2 B=0.0560 M=29.5
# Base ('7951', 'Mistos', 'COBB', 'Climatizado 2') -> A=6000.0 B=0.0481 M=32.3
# Base ('7951', 'Mistos', 'COBB', 'Convencional 1') -> A=5260.1 B=0.0533 M=30.1
# Base ('7951', 'Mistos', 'ROSS', 'Climatizado 2') -> A=4219.6 B=0.0585 M=26.7
# Base ('7951', 'Mistos', 'ROSS', 'Convencional 1') -> A=6000.0 B=0.0466 M=34.7
# Base ('81892', 'Fêmeas', 'COBB', 'Convencional 1') -> A=6000.0 B=0.0439 M=35.1
# Base ('81892', 'Fêmeas', 'ROSS', 'Convencional 1') -> A=5214.3 B=0.0495 M=32.1
# Base ('81892', 'Mistos', 'COBB', 'Convencional 1') -> A=5158.5 B=0.0500 M=32.6
# Base ('81892', 'Mistos', 'ROSS', 'Convencional 1') -> A=3988.1 B=0.0590 M=27.3
# Base ('83293', 'Fêmeas', 'COBB', 'Convencional 3') -> A=4484.1 B=0.0502 M=29.9
# Base ('8345', 'Fêmeas', 'COBB', 'Convencional 3') -> A=5131.8 B=0.0480 M=31.7
# Base ('8345', 'Fêmeas', 'ROSS', 'Convencional 3') -> A=6000.0 B=0.0440 M=36.9
# Base ('8345', 'Machos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0518 M=31.5
# Base ('8345', 'Machos', 'ROSS', 'Convencional 3') -> A=6000.0 B=0.0493 M=33.5
# Base ('8345', 'Mistos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0459 M=35.0
# Base ('8345', 'Mistos', 'ROSS', 'Convencional 3') -> A=6000.0 B=0.0440 M=38.0
# Falha curva-base para chave: ('84985', 'Fêmeas', 'COBB', 'Climatizado 2')
# Base ('84985', 'Machos', 'COBB', 'Climatizado 2') -> A=6000.0 B=0.0513 M=31.4
# Base ('84985', 'Machos', 'ROSS', 'Climatizado 2') -> A=5965.7 B=0.0526 M=30.5
# Base ('84985', 'Mistos', 'COBB', 'Climatizado 2') -> A=5751.3 B=0.0512 M=31.6
# Base ('84985', 'Mistos', 'HUBBARD', 'Climatizado 2') -> A=5099.1 B=0.0501 M=30.5
# Base ('85122', 'Fêmeas', 'COBB', 'Convencional 2') -> A=4656.5 B=0.0488 M=30.7
# Base ('85122', 'Fêmeas', 'COBB', 'Convencional 3') -> A=4809.0 B=0.0490 M=30.9
# Base ('85122', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0491 M=33.0
# Base ('85122', 'Machos', 'COBB', 'Convencional 2') -> A=5333.1 B=0.0521 M=30.3
# Base ('85122', 'Mistos', 'COBB', 'Convencional 2') -> A=4592.9 B=0.0616 M=27.9
# Base ('85122', 'Mistos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0492 M=32.8
# Base ('85122', 'Mistos', 'ROSS', 'Convencional 2') -> A=4052.8 B=0.0580 M=29.4
# Base ('85122', 'Mistos', 'ROSS', 'Convencional 3') -> A=4335.2 B=0.0585 M=29.2
# Base ('86684', 'Fêmeas', 'COBB', 'Climatizado 2') -> A=5007.0 B=0.0525 M=30.0
# Base ('86684', 'Fêmeas', 'COBB', 'Semi-climatizado') -> A=3599.2 B=0.0649 M=24.5
# Base ('86684', 'Machos', 'COBB', 'Climatizado 2') -> A=4811.8 B=0.0584 M=28.3
# Base ('86684', 'Machos', 'COBB', 'Semi-climatizado') -> A=6000.0 B=0.0508 M=31.8
# Base ('86684', 'Machos', 'ROSS', 'Climatizado 2') -> A=6000.0 B=0.0531 M=30.8
# Base ('86684', 'Mistos', 'ROSS', 'Semi-climatizado') -> A=3291.0 B=0.0664 M=26.3
# Base ('87381', 'Mistos', 'COBB', 'Convencional 2') -> A=4774.5 B=0.0592 M=29.2
# Base ('87734', 'Fêmeas', 'COBB', 'Climatizado 2') -> A=4788.2 B=0.0542 M=29.2
# Base ('87734', 'Machos', 'COBB', 'Climatizado 2') -> A=6000.0 B=0.0537 M=30.8
# Base ('87734', 'Machos', 'ROSS', 'Climatizado 2') -> A=5465.5 B=0.0537 M=29.3
# Base ('87734', 'Mistos', 'COBB', 'Climatizado 2') -> A=5180.7 B=0.0533 M=30.4
# Base ('89447', 'Fêmeas', 'COBB', 'Convencional 3') -> A=5599.6 B=0.0451 M=33.5
# Base ('89447', 'Machos', 'COBB', 'Climatizado 1') -> A=6000.0 B=0.0513 M=31.6
# Base ('89447', 'Machos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0499 M=31.6
# Base ('90009', 'Fêmeas', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0481 M=33.2
# Base ('90009', 'Machos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0524 M=31.5
# Base ('90009', 'Machos', 'ROSS', 'Convencional 3') -> A=5933.7 B=0.0501 M=33.2
# Base ('90009', 'Mistos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0515 M=33.5
# Base ('91311', 'Fêmeas', 'ROSS', 'Convencional 2') -> A=6000.0 B=0.0391 M=38.1
# Base ('91311', 'Mistos', 'COBB', 'Convencional 2') -> A=3800.5 B=0.0595 M=26.3
# Base ('93745', 'Fêmeas', 'COBB', 'Convencional 2') -> A=5825.3 B=0.0445 M=36.1
# Falha curva-base para chave: ('93745', 'Machos', 'ROSS', 'Convencional 2')
# Base ('94912', 'Fêmeas', 'COBB', 'Convencional 2') -> A=6000.0 B=0.0455 M=34.4
# Falha curva-base para chave: ('95497', 'Machos', 'ROSS', 'Convencional 2')
# Base ('95902', 'Machos', 'COBB', 'Climatizado 2') -> A=6000.0 B=0.0501 M=32.9
# Base ('96245', 'Fêmeas', 'COBB', 'Convencional 1') -> A=4889.6 B=0.0509 M=29.3
# Base ('9665', 'Fêmeas', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0425 M=36.4
# Base ('9665', 'Fêmeas', 'ROSS', 'Convencional 3') -> A=5908.6 B=0.0416 M=36.8
# Base ('9665', 'Machos', 'COBB', 'Convencional 3') -> A=5694.0 B=0.0525 M=30.9
# Base ('9665', 'Machos', 'ROSS', 'Convencional 3') -> A=5723.4 B=0.0498 M=33.0
# Base ('9665', 'Mistos', 'COBB', 'Convencional 3') -> A=6000.0 B=0.0464 M=35.1
# Base ('9665', 'Mistos', 'ROSS', 'Convencional 3') -> A=6000.0 B=0.0445 M=36.6
# Base ('97039', 'Fêmeas', 'COBB', 'Convencional 1') -> A=2127.0 B=0.0739 M=18.5
# Base ('97180', 'Machos', 'COBB', 'Climatizado 2') -> A=3531.0 B=0.0726 M=22.4
# C:\Users\erika\AppData\Local\Temp\ipykernel_13892\2786833300.py:60: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, _ = curve_fit(func, x, y, p0=p0, bounds=bounds, maxfev=maxfev)
# === Saída (primeiras linhas) ===
#      produtor    sexo  raca    tipo_aviario tipo_ajuste modelo_escolhido  \
# 1461    58294  Machos  ROSS   Climatizado 2    completo        Logistico
# 1275    58213  Machos  COBB   Climatizado 2    completo         Richards
# 1250    57814  Machos  COBB   Climatizado 2    completo         Richards
# 1713    60211  Machos  COBB  Convencional 2    completo         Richards
# 1612    58371  Machos  COBB   Climatizado 2    completo         Gompertz
# 522     30030  Machos  COBB   Climatizado 2    completo        Logistico
# 1387    58253  Machos  COBB  Convencional 1    completo         Richards
# 684     47320  Machos  COBB   Climatizado 2    completo         Richards
# 1790    63291  Machos  COBB   Climatizado 2    completo         Gompertz
# 1169    55911  Machos  COBB   Climatizado 2    completo         Richards
# 1955    69859  Machos  COBB  Convencional 2    completo         Richards
# 1392    58254  Machos  COBB  Convencional 3    completo         Richards
# 1727    60712  Machos  COBB  Convencional 3    completo         Gompertz
# 763     48617  Machos  COBB   Climatizado 2    completo         Richards
# 764     48617  Machos  COBB  Convencional 3    completo         Gompertz
# 1892    66732  Machos  COBB   Climatizado 2    completo         Richards
# 1460    58294  Machos  COBB  Convencional 3    completo        Logistico
# 2114    89447  Machos  COBB   Climatizado 1    completo         Richards
# 1213    56731  Mistos  COBB   Climatizado 2    completo         Richards
# 1593    58366  Machos  ROSS   Climatizado 2    completo         Richards
#
#                  A            K         B          M  ...  FLAG_ASSINTOTE  \
# 1461  4.086235e+01  3743.765632  0.133088        NaN  ...              ok
# 1275  1.352236e-01  4521.239821  0.082303  15.076692  ...              ok
# 1250  2.028038e-16  4576.037347  0.080667  15.182679  ...              ok
# 1713  2.653641e-14  4481.856535  0.083995  17.003206  ...              ok
# 1612  5.452374e+03          NaN  0.056650  28.956330  ...              ok
# 522   3.643958e+01  3799.333589  0.128041        NaN  ...              ok
# 1387  1.981648e-06  5405.093350  0.068061  10.989444  ...              ok
# 684   3.545952e-13  4607.567278  0.079573  15.064021  ...              ok
# 1790  5.858353e+03          NaN  0.052602  30.417865  ...              ok
# 1169  5.679353e-02  4274.839306  0.084681  13.832274  ...              ok
# 1955  4.779531e-06  5475.772729  0.068519  13.386998  ...              ok
# 1392  7.209169e-06  5209.350546  0.068393   9.469971  ...              ok
# 1727  6.000000e+03          NaN  0.051850  31.106895  ...              ok
# 763   1.855097e-02  5350.868320  0.066776   9.729017  ...              ok
# 764   6.000000e+03          NaN  0.051326  31.082263  ...              ok
# 1892  5.455184e-02  4920.241000  0.072544  11.262513  ...              ok
# 1460  4.269783e+01  3529.445347  0.140091        NaN  ...              ok
# 2114  1.936651e-17  6000.000000  0.064170  15.510157  ...              ok
# 1213  1.652930e-06  5487.530784  0.067033  12.109381  ...              ok
# 1593  2.845724e-16  4252.238585  0.098980  23.461639  ...              ok
#
#             R2  R2_LOOCV  RMSE_LOOCV  IDADE_PARA_2800G  \
# 1461  0.999687  0.997576   44.947590         36.049097
# 1275  0.999908  0.997950   51.225187         36.090455
# 1250  0.999941  0.998024   40.242629         36.110848
# 1713  0.999972  0.999256   24.677077         36.117870
# 1612  0.999594  0.998756   40.191483         36.119920
# 522   0.997559  0.995640   67.692781         36.128565
# 1387  0.999975  0.998768   31.555772         36.155106
# 684   0.999909  0.998630   41.529462         36.159502
# 1790  0.999981  0.999930    9.526582         36.187059
# 1169  0.999998  0.999623   17.657614         36.237647
# 1955  0.999939  0.992757   75.904748         36.240551
# 1392  0.999983  0.998953   28.898669         36.329701
# 1727  0.999968  0.999933    9.319314         36.345547
# 763   0.999961  0.999523   24.825282         36.371849
# 764   0.999961  0.999858   13.466117         36.374394
# 1892  0.999978  0.999712   19.159092         36.396066
# 1460  0.999774  0.998810   31.477328         36.399416
# 2114  0.999609  0.994808   62.915756         36.414481
# 1213  0.999933  0.997937   40.176510         36.414861
# 1593  0.999942  0.998324   46.017226         36.444550
#
#       IDADE_PARA_2800G_AJUST  FLAG_IDADE_2800  peso_previsto_42 peso_real_42  \
# 1461               36.049097               ok       3247.913901          NaN
# 1275               36.090455               ok       3336.856444  3340.000000
# 1250               36.110848               ok       3339.168419          NaN
# 1713               36.117870               ok       3329.856382          NaN
# 1612               36.119920               ok       3381.852857  3380.000000
# 522                36.128565               ok       3252.048802  3254.142857
# 1387               36.155106               ok       3433.922744          NaN
# 684                36.159502               ok       3336.628840  3337.500000
# 1790               36.187059               ok       3401.136067  3400.000000
# 1169               36.237647               ok       3274.186390          NaN
# 1955               36.240551               ok       3437.206479          NaN
# 1392               36.329701               ok       3385.042753          NaN
# 1727               36.345547               ok       3398.352954  3400.000000
# 763                36.371849               ok       3393.498593  3400.000000
# 764                36.374394               ok       3389.760944  3400.000000
# 1892               36.396066               ok       3349.151671  3350.000000
# 1460               36.399416               ok       3154.459067          NaN
# 2114               36.414481               ok       3459.611965          NaN
# 1213               36.414861               ok       3411.356479          NaN
# 1593               36.444550               ok       3300.529276  3300.000000
#
#       num_pontos
# 1461           5
# 1275           6
# 1250           5
# 1713           5
# 1612           6
# 522           11
# 1387           5
# 684            6
# 1790           6
# 1169           5
# 1955           5
# 1392           5
# 1727           6
# 763            6
# 764            6
# 1892           6
# 1460           5
# 2114           5
# 1213           5
# 1593           6
#
# [20 rows x 22 columns]
#
# ✅ Arquivo gerado em: C:\Users\erika\OneDrive\Área de Trabalho\AVICOLA\resultado_modelagem_Sigmoide.csv
